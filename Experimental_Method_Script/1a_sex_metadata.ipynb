# %%
# Creating a baseline metadata
import pandas as pd
import os
import numpy as np

parent = '/home/jkim/research/peds_cxr/'
metadata = pd.read_csv(parent + '25variation/metadata/final/aggregate/aggregate_metadata_seed_9.csv')

def create_correct_patient_id(row):
    if row['Dataset'] == 'VinDR':
        return row['Image Index'].replace('.png', '')
    elif row['Dataset'] == 'NIH':
        patient_id, _ = row['Image Index'].split('_')
        return patient_id
    else:
        return None

def categorize_age_group(row):
    if 0 <= row['Patient Age'] <= 5:
        return 'young'
    elif 6 <= row['Patient Age'] <= 17:
        return 'old'
    else:
        return 'not applicable'

metadata['Age Group'] = metadata.apply(categorize_age_group, axis=1)
metadata['Patient_id'] = metadata.apply(create_correct_patient_id, axis=1) 

column = ['Image Index','Patient_id','Dataset','Patient Age','Age Group','Patient Gender','No Finding','Cardiomegaly','Consolidation','Infiltration','Mass/Nodule','Pneumonia']
metadata = metadata[column]

# Create Positive Label adn Patient Patient column
positive_conditions = ['Pneumonia', 'Cardiomegaly', 'Consolidation', 'Infiltration', 'Mass/Nodule'] 
metadata['Positive_Label'] = metadata[positive_conditions].any(axis=1).astype(int)
positive_patients = metadata[metadata['Positive_Label'] == 1]['Patient_id'].unique()
metadata['Positive_Patient'] = metadata['Patient_id'].isin(positive_patients).astype(int)


metadata.to_csv(parent + 'no_finding/metadata/base_metadata.csv', index=False)

# %%
import os 
predefined_seeds = [2358, 4563, 7894, 13289, 15892, 19756, 23890, 27456, 30890, 34905, 38764, 42136, 46578, 50349, 54892, 59871, 63912, 68354, 72109, 76845, 80492, 84910, 89357, 93450, 97910]

for seed in predefined_seeds:
    os.makedirs(parent + f'no_finding/metadata/aggregate_sex_nf/aggregate_sex_nf_seed_{seed}', exist_ok=True)
    os.makedirs(parent + f'no_finding/metadata/aggregate_age_nf/aggregate_age_nf_seed_{seed}', exist_ok=True)
    os.makedirs(parent + f'no_finding/experiment/metadata_count/seed{seed}', exist_ok=True)
    os.makedirs(parent + f'no_finding/experiment/metadata_count/seed{seed}', exist_ok=True)

# %%
import pandas as pd
import random
import os

# Load the CSV file
file_path = parent + '/no_finding/metadata/base_metadata.csv'
df = pd.read_csv(file_path)

# Define the ratios and diagnostic labels
ratios = [(0, 100), (25, 75), (50, 50), (75, 25), (100, 0)]
diagnostic_labels = ['Cardiomegaly', 'Consolidation', 'Infiltration', 'Mass/Nodule', 'Pneumonia']
dl = ['No Finding', 'Cardiomegaly', 'Consolidation', 'Infiltration', 'Mass/Nodule', 'Pneumonia']

# Function to calculate and print diagnostic label counts for each set
def print_label_counts(df, set_name):
    print(f"\nDiagnostic Label Counts for {set_name} Set:")
    for gender_group in ['M', 'F']:
        print(f"Gender Group: {gender_group}")
        df_set = df[(df['Set'].str.contains(set_name)) & (df['Patient Gender'] == gender_group)]
        label_counts = df_set[dl].sum()
        print(label_counts)

# Helper function to assign patients to a given set
def assign_patients_to_set(df, gender_group, positive_patient, positive_label, total_count, set_name, seed, max_images_per_patient=None):
    df_gender_group = df[(df['Patient Gender'] == gender_group) & (df['Set'] == '')] 
    
    # Filter for patients with specified positive or negative label
    if positive_patient == 1:
        patients = df_gender_group[df_gender_group['Positive_Patient'] == positive_patient].groupby('Patient_id').filter(lambda x: len(x) <= 3 if max_images_per_patient else True)
    else:
        patients = df_gender_group[(df_gender_group['Positive_Label'] == positive_label) & (df_gender_group['Positive_Patient'] == positive_patient)].groupby('Patient_id').filter(lambda x: len(x) <= 3 if max_images_per_patient else True)

    unique_patients = patients['Patient_id'].unique()
    
    # Shuffle patients
    random.seed(seed)
    random.shuffle(unique_patients)
    
    count = 0  # Track the number of images assigned
    assigned_patients = set()
    
    for patient_id in unique_patients: 
        patient_rows = df[df['Patient_id'] == patient_id] 
        if positive_patient == 1: 
            label_count = patient_rows['Positive_Label'].sum()  # Count positive images 
        else: 
            label_count = len(patient_rows[patient_rows['Positive_Label'] == positive_label])  # Count negative images 

        # Check if adding this patient exceeds the total count limit
        if count + label_count <= total_count:
            df.loc[df['Patient_id'] == patient_id, 'Set'] = set_name  # Assign patient to the set
            count += label_count
            assigned_patients.add(patient_id)  # Keep track of assigned patients

        if count >= total_count:
            break
    
    return df, assigned_patients

# Function to check if each diagnostic label in each set contains at least 2 images for old and young groups
def check_age_balance_per_label(df, set_name, min_count=2):
    for label in diagnostic_labels:
        df_filtered = df[(df['Set'].str.contains(set_name)) & (df['Positive_Label'] == 1) & (df[label] == 1)]
        old_count = df_filtered[df_filtered['Age Group'] == 'old'].shape[0]
        young_count = df_filtered[df_filtered['Age Group'] == 'young'].shape[0]
        if old_count < min_count or young_count < min_count:
            print(f"{set_name} set for label {label} does not meet age balance. Old: {old_count}, Young: {young_count}")
            return False
    return True

# Function to perform assignments with checking conditions and changing seeds if conditions aren't met
def assign_with_conditions(df, gender_group, positive_patient, positive_label, total_count, set_name, seed, max_images_per_patient=None, min_count=1, retry_limit=2000):
    # Skip the function entirely if the ratio for this sex group is 0
    if (gender_group == 'M' and total_count == 0) or (gender_group == 'F' and total_count == 0):
        print(f"Skipping {set_name} assignment for {gender_group} as the ratio is 0.")
        return df

    retry_count = 0
    while retry_count < retry_limit:  # Retry until conditions are met or retry limit is reached
        df_temp = df[df['Set'] == ''].copy()  # Work with a copy of the original DataFrame

        # Perform the assignment
        df_temp, _ = assign_patients_to_set(df_temp, gender_group, positive_patient, positive_label, total_count, set_name, seed, max_images_per_patient)

        # Check if the assigned set meets the age balance condition per diagnostic label
        if check_age_balance_per_label(df_temp, set_name, min_count):
            # If conditions are met, update the original DataFrame and break
            df.update(df_temp)
            print(f"Conditions met for {set_name} with seed {seed}.")
            return df
        else:
            retry_count += 1
            # Change to a new random seed
            seed = seed + 1
            print(f"Conditions not met for {set_name}. Changing seed to {seed} and retrying... (Attempt {retry_count}/{retry_limit})")

    # If retry limit is reached, raise an error to stop the code
    error_message = f"Retry limit of {retry_limit} reached for {set_name}. The last seed {seed} did not meet the requirement."
    print(error_message)
    raise RuntimeError(error_message)


    # Print details of the unmet requirements
    for label in diagnostic_labels:
        df_filtered = df_temp[(df_temp['Set'].str.contains(set_name)) & (df_temp['Positive_Label'] == 1) & (df_temp[label] == 1)]
        old_count = df_filtered[df_filtered['Age Group'] == 'old'].shape[0]
        young_count = df_filtered[df_filtered['Age Group'] == 'young'].shape[0]
        print(f"Label {label} in {set_name} set: Old: {old_count}, Young: {young_count}")

    return df

# Create the datasets using the new function
dfs = {}  # Dictionary to hold the generated DataFrames

# First, assign the test set (this will remain the same across all splits)
df['Set'] = ''  # Reset the 'Set' column
male_ratio = 1
female_ratio = 1
df = assign_with_conditions(df, 'M', 1, 1, 157, 'test', seed=10, max_images_per_patient=3)
df = assign_with_conditions(df, 'F', 1, 1, 157, 'test', seed=10, max_images_per_patient=3)
df = assign_patients_to_set(df, 'M', 0, 0, 378, 'test', seed=10, max_images_per_patient=3)[0]
df = assign_patients_to_set(df, 'F', 0, 0, 378, 'test', seed=10, max_images_per_patient=3)[0]

print_label_counts(df, 'test')

# Now, iterate over each ratio and seed to create datasets
for seed_idx, seed in enumerate(predefined_seeds):
    for ratio_idx, (male_ratio, female_ratio) in enumerate(ratios):
        # Create a copy of the DataFrame with the test set already assigned
        df_copy = df.copy()

        # Store the DataFrame in the dictionary with a key based on the ratio and seed
        dataset_key = f'df_ratio_{male_ratio}_{female_ratio}_seed_{seed}'
        dfs[dataset_key] = df_copy

        # Create validation set (157 positive, 378 negative)
        validation_set_name = 'val'
        dfs[dataset_key] = assign_with_conditions(dfs[dataset_key], 'M', 1, 1, int(157 * (male_ratio / 100)), validation_set_name, seed, max_images_per_patient=3)
        dfs[dataset_key] = assign_with_conditions(dfs[dataset_key], 'F', 1, 1, int(157 * (female_ratio / 100)), validation_set_name, seed, max_images_per_patient=3)
        dfs[dataset_key] = assign_patients_to_set(dfs[dataset_key], 'M', 0, 0, int(378 * (male_ratio / 100)), validation_set_name, seed, max_images_per_patient=3)[0]
        dfs[dataset_key] = assign_patients_to_set(dfs[dataset_key], 'F', 0, 0, int(378 * (female_ratio / 100)), validation_set_name, seed, max_images_per_patient=3)[0]

        # Create training set (1255 positive, 3023 negative)
        training_set_name = 'train'
        dfs[dataset_key] = assign_with_conditions(dfs[dataset_key], 'M', 1, 1, int(1255 * (male_ratio / 100)), training_set_name, seed)
        dfs[dataset_key] = assign_with_conditions(dfs[dataset_key], 'F', 1, 1, int(1255 * (female_ratio / 100)), training_set_name, seed)
        dfs[dataset_key] = assign_patients_to_set(dfs[dataset_key], 'M', 0, 0, int(3023 * (male_ratio / 100)), training_set_name, seed)[0]
        dfs[dataset_key] = assign_patients_to_set(dfs[dataset_key], 'F', 0, 0, int(3023 * (female_ratio / 100)), training_set_name, seed)[0]

        # Save the generated DataFrame to a CSV file
        output_path = os.path.join(parent, f'no_finding/metadata/aggregate_sex_nf/aggregate_sex_nf_seed_{seed}/sex_{male_ratio}_seed_{seed}.csv')
        dfs[dataset_key].to_csv(output_path, index=False)
# Out:
# test set for label Cardiomegaly does not meet age balance. Old: 0, Young: 9
# Conditions not met for test. Changing seed to 11 and retrying... (Attempt 1/2000)
# Conditions met for test with seed 11.
# test set for label Cardiomegaly does not meet age balance. Old: 0, Young: 15
# Conditions not met for test. Changing seed to 11 and retrying... (Attempt 1/2000)
# test set for label Cardiomegaly does not meet age balance. Old: 0, Young: 12
# Conditions not met for test. Changing seed to 12 and retrying... (Attempt 2/2000)
# Conditions met for test with seed 12.
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
# Skipping val assignment for M as the ratio is 0.
# Conditions met for val with seed 2358.
# Skipping train assignment for M as the ratio is 0.
# Conditions met for train with seed 2358.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 2359 and retrying... (Attempt 1/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 2360 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 2361 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 2362 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 2363 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 2364 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 2365 and retrying... (Attempt 7/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 10
# Conditions not met for val. Changing seed to 2366 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 2367 and retrying... (Attempt 9/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 2368 and retrying... (Attempt 10/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 2369 and retrying... (Attempt 11/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 2370 and retrying... (Attempt 12/2000)
# Conditions met for val with seed 2370.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 2359 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 2360 and retrying... (Attempt 2/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 10
# Conditions not met for val. Changing seed to 2361 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 2362 and retrying... (Attempt 4/2000)
# Conditions met for val with seed 2362.
# Conditions met for train with seed 2358.
# Conditions met for train with seed 2358.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 2359 and retrying... (Attempt 1/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 2360 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 2361 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 2362 and retrying... (Attempt 4/2000)
# Conditions met for val with seed 2362.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 2359 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 2360 and retrying... (Attempt 2/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 2361 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 2362 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 0
# Conditions not met for val. Changing seed to 2363 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 2364 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 2365 and retrying... (Attempt 7/2000)
# Conditions met for val with seed 2365.
# Conditions met for train with seed 2358.
# Conditions met for train with seed 2358.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 2359 and retrying... (Attempt 1/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 2360 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 14
# Conditions not met for val. Changing seed to 2361 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 2362 and retrying... (Attempt 4/2000)
# Conditions met for val with seed 2362.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 2359 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 2360 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 2361 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 2362 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 0
# Conditions not met for val. Changing seed to 2363 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 2364 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 2365 and retrying... (Attempt 7/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 2366 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 2367 and retrying... (Attempt 9/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 2368 and retrying... (Attempt 10/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 2369 and retrying... (Attempt 11/2000)
# Conditions met for val with seed 2369.
# Conditions met for train with seed 2358.
# Conditions met for train with seed 2358.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 14
# Conditions not met for val. Changing seed to 2359 and retrying... (Attempt 1/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 11
# Conditions not met for val. Changing seed to 2360 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 16
# Conditions not met for val. Changing seed to 2361 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 13
# Conditions not met for val. Changing seed to 2362 and retrying... (Attempt 4/2000)
# Conditions met for val with seed 2362.
# Skipping val assignment for F as the ratio is 0.
# Conditions met for train with seed 2358.
# Skipping train assignment for F as the ratio is 0.
# Skipping val assignment for M as the ratio is 0.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 12
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 4564.
# Skipping train assignment for M as the ratio is 0.
# Conditions met for train with seed 4563.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 4565 and retrying... (Attempt 2/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 12
# Conditions not met for val. Changing seed to 4566 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 4567 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 4568 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 4569 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 4570 and retrying... (Attempt 7/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 4571 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 4572 and retrying... (Attempt 9/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 4573 and retrying... (Attempt 10/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 4574 and retrying... (Attempt 11/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 4575 and retrying... (Attempt 12/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 4576 and retrying... (Attempt 13/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 4577 and retrying... (Attempt 14/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 4578 and retrying... (Attempt 15/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 4579 and retrying... (Attempt 16/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 4580 and retrying... (Attempt 17/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 4581 and retrying... (Attempt 18/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 4582 and retrying... (Attempt 19/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 4583 and retrying... (Attempt 20/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 4584 and retrying... (Attempt 21/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 4585 and retrying... (Attempt 22/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 4586 and retrying... (Attempt 23/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 4587 and retrying... (Attempt 24/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 4588 and retrying... (Attempt 25/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 4589 and retrying... (Attempt 26/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 4590 and retrying... (Attempt 27/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 4591 and retrying... (Attempt 28/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 4592 and retrying... (Attempt 29/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 4593 and retrying... (Attempt 30/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 4594 and retrying... (Attempt 31/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 4595 and retrying... (Attempt 32/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 4596 and retrying... (Attempt 33/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 4597 and retrying... (Attempt 34/2000)
# Conditions met for val with seed 4597.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 4564.
# Conditions met for train with seed 4563.
# Conditions met for train with seed 4563.
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 27
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 11
# Conditions not met for val. Changing seed to 4565 and retrying... (Attempt 2/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 19
# Conditions not met for val. Changing seed to 4566 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 4567 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 4568 and retrying... (Attempt 5/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 4569 and retrying... (Attempt 6/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 22
# Conditions not met for val. Changing seed to 4570 and retrying... (Attempt 7/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 4571 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 4572 and retrying... (Attempt 9/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 4573 and retrying... (Attempt 10/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 4574 and retrying... (Attempt 11/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 10
# Conditions not met for val. Changing seed to 4575 and retrying... (Attempt 12/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 4576 and retrying... (Attempt 13/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 4577 and retrying... (Attempt 14/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 15
# Conditions not met for val. Changing seed to 4578 and retrying... (Attempt 15/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 10
# Conditions not met for val. Changing seed to 4579 and retrying... (Attempt 16/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 4580 and retrying... (Attempt 17/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 4581 and retrying... (Attempt 18/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 18
# Conditions not met for val. Changing seed to 4582 and retrying... (Attempt 19/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 4583 and retrying... (Attempt 20/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 4584 and retrying... (Attempt 21/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 4585 and retrying... (Attempt 22/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 4586 and retrying... (Attempt 23/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 4587 and retrying... (Attempt 24/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 26
# Conditions not met for val. Changing seed to 4588 and retrying... (Attempt 25/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 4589 and retrying... (Attempt 26/2000)
# Conditions met for val with seed 4589.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 4564.
# Conditions met for train with seed 4563.
# Conditions met for train with seed 4563.
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 40
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 14
# Conditions not met for val. Changing seed to 4565 and retrying... (Attempt 2/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 24
# Conditions not met for val. Changing seed to 4566 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 10
# Conditions not met for val. Changing seed to 4567 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 10
# Conditions not met for val. Changing seed to 4568 and retrying... (Attempt 5/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 4569 and retrying... (Attempt 6/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 49
# Conditions not met for val. Changing seed to 4570 and retrying... (Attempt 7/2000)
# Conditions met for val with seed 4570.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 4564.
# Conditions met for train with seed 4563.
# Conditions met for train with seed 4563.
# Conditions met for val with seed 4563.
# Skipping val assignment for F as the ratio is 0.
# Conditions met for train with seed 4563.
# Skipping train assignment for F as the ratio is 0.
# Skipping val assignment for M as the ratio is 0.
# Conditions met for val with seed 7894.
# Skipping train assignment for M as the ratio is 0.
# Conditions met for train with seed 7894.
# Conditions met for val with seed 7894.
# Conditions met for val with seed 7894.
# Conditions met for train with seed 7894.
# Conditions met for train with seed 7894.
# Conditions met for val with seed 7894.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 7895 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 7896 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 7897 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 10
# Conditions not met for val. Changing seed to 7898 and retrying... (Attempt 4/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 16
# Conditions not met for val. Changing seed to 7899 and retrying... (Attempt 5/2000)
# Conditions met for val with seed 7899.
# Conditions met for train with seed 7894.
# Conditions met for train with seed 7894.
# Conditions met for val with seed 7894.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 7895 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 7896 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 7897 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 7898 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 7899 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 7900 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 7901 and retrying... (Attempt 7/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 7902 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 7903 and retrying... (Attempt 9/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 7904 and retrying... (Attempt 10/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 7905 and retrying... (Attempt 11/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 7906 and retrying... (Attempt 12/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 7907 and retrying... (Attempt 13/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 7908 and retrying... (Attempt 14/2000)
# val set for label Consolidation does not meet age balance. Old: 1, Young: 0
# Conditions not met for val. Changing seed to 7909 and retrying... (Attempt 15/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 7910 and retrying... (Attempt 16/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 7911 and retrying... (Attempt 17/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 0
# Conditions not met for val. Changing seed to 7912 and retrying... (Attempt 18/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 7913 and retrying... (Attempt 19/2000)
# val set for label Infiltration does not meet age balance. Old: 0, Young: 23
# Conditions not met for val. Changing seed to 7914 and retrying... (Attempt 20/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 7915 and retrying... (Attempt 21/2000)
# val set for label Infiltration does not meet age balance. Old: 0, Young: 23
# Conditions not met for val. Changing seed to 7916 and retrying... (Attempt 22/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 7917 and retrying... (Attempt 23/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 7918 and retrying... (Attempt 24/2000)
# Conditions met for val with seed 7918.
# Conditions met for train with seed 7894.
# Conditions met for train with seed 7894.
# Conditions met for val with seed 7894.
# Skipping val assignment for F as the ratio is 0.
# Conditions met for train with seed 7894.
# Skipping train assignment for F as the ratio is 0.
# Skipping val assignment for M as the ratio is 0.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 15
# Conditions not met for val. Changing seed to 13290 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 13290.
# Skipping train assignment for M as the ratio is 0.
# Conditions met for train with seed 13289.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 13290 and retrying... (Attempt 1/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 15
# Conditions not met for val. Changing seed to 13291 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 13292 and retrying... (Attempt 3/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 13293 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 1, Young: 0
# Conditions not met for val. Changing seed to 13294 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 13295 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 13296 and retrying... (Attempt 7/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 13297 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 13298 and retrying... (Attempt 9/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 13299 and retrying... (Attempt 10/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 13300 and retrying... (Attempt 11/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 0
# Conditions not met for val. Changing seed to 13301 and retrying... (Attempt 12/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 13302 and retrying... (Attempt 13/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 13303 and retrying... (Attempt 14/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 13304 and retrying... (Attempt 15/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 13305 and retrying... (Attempt 16/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 13306 and retrying... (Attempt 17/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 13307 and retrying... (Attempt 18/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 13308 and retrying... (Attempt 19/2000)
# Conditions met for val with seed 13308.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 13
# Conditions not met for val. Changing seed to 13290 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 13290.
# Conditions met for train with seed 13289.
# Conditions met for train with seed 13289.
# val set for label Consolidation does not meet age balance. Old: 0, Young: 10
# Conditions not met for val. Changing seed to 13290 and retrying... (Attempt 1/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 29
# Conditions not met for val. Changing seed to 13291 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 13292 and retrying... (Attempt 3/2000)
# Conditions met for val with seed 13292.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 13290 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 13290.
# Conditions met for train with seed 13289.
# Conditions met for train with seed 13289.
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 50
# Conditions not met for val. Changing seed to 13290 and retrying... (Attempt 1/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 46
# Conditions not met for val. Changing seed to 13291 and retrying... (Attempt 2/2000)
# Conditions met for val with seed 13291.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 13290 and retrying... (Attempt 1/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 13291 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 13292 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 13293 and retrying... (Attempt 4/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 13294 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 13295 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 13296 and retrying... (Attempt 7/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 13297 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 13298 and retrying... (Attempt 9/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 13299 and retrying... (Attempt 10/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 13300 and retrying... (Attempt 11/2000)
# val set for label Infiltration does not meet age balance. Old: 0, Young: 25
# Conditions not met for val. Changing seed to 13301 and retrying... (Attempt 12/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 13302 and retrying... (Attempt 13/2000)
# Conditions met for val with seed 13302.
# Conditions met for train with seed 13289.
# Conditions met for train with seed 13289.
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 67
# Conditions not met for val. Changing seed to 13290 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 13290.
# Skipping val assignment for F as the ratio is 0.
# Conditions met for train with seed 13289.
# Skipping train assignment for F as the ratio is 0.
# Skipping val assignment for M as the ratio is 0.
# Conditions met for val with seed 15892.
# Skipping train assignment for M as the ratio is 0.
# Conditions met for train with seed 15892.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15893 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 15894 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 15895 and retrying... (Attempt 3/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15896 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15897 and retrying... (Attempt 5/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 15898 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 15899 and retrying... (Attempt 7/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 15900 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 15901 and retrying... (Attempt 9/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15902 and retrying... (Attempt 10/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15903 and retrying... (Attempt 11/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 15904 and retrying... (Attempt 12/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15905 and retrying... (Attempt 13/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15906 and retrying... (Attempt 14/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 15907 and retrying... (Attempt 15/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15908 and retrying... (Attempt 16/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15909 and retrying... (Attempt 17/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 15910 and retrying... (Attempt 18/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15911 and retrying... (Attempt 19/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 15912 and retrying... (Attempt 20/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15913 and retrying... (Attempt 21/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 15914 and retrying... (Attempt 22/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15915 and retrying... (Attempt 23/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15916 and retrying... (Attempt 24/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 15917 and retrying... (Attempt 25/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 15918 and retrying... (Attempt 26/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15919 and retrying... (Attempt 27/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15920 and retrying... (Attempt 28/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15921 and retrying... (Attempt 29/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 15922 and retrying... (Attempt 30/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15923 and retrying... (Attempt 31/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15924 and retrying... (Attempt 32/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15925 and retrying... (Attempt 33/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15926 and retrying... (Attempt 34/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 15927 and retrying... (Attempt 35/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 16
# Conditions not met for val. Changing seed to 15928 and retrying... (Attempt 36/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 15929 and retrying... (Attempt 37/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 15930 and retrying... (Attempt 38/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 12
# Conditions not met for val. Changing seed to 15931 and retrying... (Attempt 39/2000)
# val set for label Consolidation does not meet age balance. Old: 1, Young: 0
# Conditions not met for val. Changing seed to 15932 and retrying... (Attempt 40/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 15933 and retrying... (Attempt 41/2000)
# Conditions met for val with seed 15933.
# Conditions met for val with seed 15892.
# Conditions met for train with seed 15892.
# Conditions met for train with seed 15892.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 11
# Conditions not met for val. Changing seed to 15893 and retrying... (Attempt 1/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 15894 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 15895 and retrying... (Attempt 3/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 15896 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15897 and retrying... (Attempt 5/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 15898 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 15899 and retrying... (Attempt 7/2000)
# Conditions met for val with seed 15899.
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 33
# Conditions not met for val. Changing seed to 15893 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 15893.
# Conditions met for train with seed 15892.
# Conditions met for train with seed 15892.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 12
# Conditions not met for val. Changing seed to 15893 and retrying... (Attempt 1/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 15894 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 10
# Conditions not met for val. Changing seed to 15895 and retrying... (Attempt 3/2000)
# Conditions met for val with seed 15895.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 0
# Conditions not met for val. Changing seed to 15893 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 15894 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15895 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 15896 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15897 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15898 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15899 and retrying... (Attempt 7/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15900 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15901 and retrying... (Attempt 9/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 15902 and retrying... (Attempt 10/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 15903 and retrying... (Attempt 11/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 15904 and retrying... (Attempt 12/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 15905 and retrying... (Attempt 13/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 15906 and retrying... (Attempt 14/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 15907 and retrying... (Attempt 15/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15908 and retrying... (Attempt 16/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 15909 and retrying... (Attempt 17/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 15910 and retrying... (Attempt 18/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15911 and retrying... (Attempt 19/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 15912 and retrying... (Attempt 20/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 15913 and retrying... (Attempt 21/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 15914 and retrying... (Attempt 22/2000)
# Conditions met for val with seed 15914.
# Conditions met for train with seed 15892.
# Conditions met for train with seed 15892.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 16
# Conditions not met for val. Changing seed to 15893 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 15893.
# Skipping val assignment for F as the ratio is 0.
# Conditions met for train with seed 15892.
# Skipping train assignment for F as the ratio is 0.
# Skipping val assignment for M as the ratio is 0.
# Conditions met for val with seed 19756.
# Skipping train assignment for M as the ratio is 0.
# Conditions met for train with seed 19756.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 19757 and retrying... (Attempt 1/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 19758 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 19759 and retrying... (Attempt 3/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 11
# Conditions not met for val. Changing seed to 19760 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 19761 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 19762 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# ...
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 89388 and retrying... (Attempt 31/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 89389 and retrying... (Attempt 32/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 89390 and retrying... (Attempt 33/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 89391 and retrying... (Attempt 34/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 89392 and retrying... (Attempt 35/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 89393 and retrying... (Attempt 36/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 89394 and retrying... (Attempt 37/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 89395 and retrying... (Attempt 38/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 89396 and retrying... (Attempt 39/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 89397 and retrying... (Attempt 40/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 89398 and retrying... (Attempt 41/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 89399 and retrying... (Attempt 42/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 89400 and retrying... (Attempt 43/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 89401 and retrying... (Attempt 44/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 89402 and retrying... (Attempt 45/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 89403 and retrying... (Attempt 46/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 89404 and retrying... (Attempt 47/2000)
# Conditions met for val with seed 89404.
# Conditions met for val with seed 89357.
# Conditions met for train with seed 89357.
# Conditions met for train with seed 89357.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 89358 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 89359 and retrying... (Attempt 2/2000)
# Conditions met for val with seed 89359.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 11
# Conditions not met for val. Changing seed to 89358 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 89359 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 10
# Conditions not met for val. Changing seed to 89360 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 89361 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 89362 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 89363 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 89364 and retrying... (Attempt 7/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 31
# Conditions not met for val. Changing seed to 89365 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 11
# Conditions not met for val. Changing seed to 89366 and retrying... (Attempt 9/2000)
# Conditions met for val with seed 89366.
# Conditions met for train with seed 89357.
# Conditions met for train with seed 89357.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 89358 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 89358.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 89358 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 89359 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 89360 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 89361 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 89362 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 89363 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 89364 and retrying... (Attempt 7/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 89365 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 89366 and retrying... (Attempt 9/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 12
# Conditions not met for val. Changing seed to 89367 and retrying... (Attempt 10/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 89368 and retrying... (Attempt 11/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 89369 and retrying... (Attempt 12/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 89370 and retrying... (Attempt 13/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 89371 and retrying... (Attempt 14/2000)
# Conditions met for val with seed 89371.
# Conditions met for train with seed 89357.
# Conditions met for train with seed 89357.
# Conditions met for val with seed 89357.
# Skipping val assignment for F as the ratio is 0.
# Conditions met for train with seed 89357.
# Skipping train assignment for F as the ratio is 0.
# Skipping val assignment for M as the ratio is 0.
# Conditions met for val with seed 93450.
# Skipping train assignment for M as the ratio is 0.
# Conditions met for train with seed 93450.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 93451 and retrying... (Attempt 1/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 93452 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 93453 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 93454 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 93455 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 93456 and retrying... (Attempt 6/2000)
# Conditions met for val with seed 93456.
# Conditions met for val with seed 93450.
# Conditions met for train with seed 93450.
# Conditions met for train with seed 93450.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 93451 and retrying... (Attempt 1/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 93452 and retrying... (Attempt 2/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 93453 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 93454 and retrying... (Attempt 4/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 93455 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 93456 and retrying... (Attempt 6/2000)
# Conditions met for val with seed 93456.
# Conditions met for val with seed 93450.
# Conditions met for train with seed 93450.
# Conditions met for train with seed 93450.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 93451 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 93451.
# Conditions met for val with seed 93450.
# Conditions met for train with seed 93450.
# Conditions met for train with seed 93450.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 10
# Conditions not met for val. Changing seed to 93451 and retrying... (Attempt 1/2000)
# Conditions met for val with seed 93451.
# Skipping val assignment for F as the ratio is 0.
# Conditions met for train with seed 93450.
# Skipping train assignment for F as the ratio is 0.
# Skipping val assignment for M as the ratio is 0.
# Conditions met for val with seed 97910.
# Skipping train assignment for M as the ratio is 0.
# Conditions met for train with seed 97910.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 97911 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 97912 and retrying... (Attempt 2/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 1
# Conditions not met for val. Changing seed to 97913 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 97914 and retrying... (Attempt 4/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 97915 and retrying... (Attempt 5/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 97916 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 97917 and retrying... (Attempt 7/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 97918 and retrying... (Attempt 8/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 97919 and retrying... (Attempt 9/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 97920 and retrying... (Attempt 10/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 97921 and retrying... (Attempt 11/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 6
# Conditions not met for val. Changing seed to 97922 and retrying... (Attempt 12/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 4
# Conditions not met for val. Changing seed to 97923 and retrying... (Attempt 13/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 97924 and retrying... (Attempt 14/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 97925 and retrying... (Attempt 15/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 97926 and retrying... (Attempt 16/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 2
# Conditions not met for val. Changing seed to 97927 and retrying... (Attempt 17/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 97928 and retrying... (Attempt 18/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 15
# Conditions not met for val. Changing seed to 97929 and retrying... (Attempt 19/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 3
# Conditions not met for val. Changing seed to 97930 and retrying... (Attempt 20/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 9
# Conditions not met for val. Changing seed to 97931 and retrying... (Attempt 21/2000)
# Conditions met for val with seed 97931.
# Conditions met for val with seed 97910.
# Conditions met for train with seed 97910.
# Conditions met for train with seed 97910.
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 97911 and retrying... (Attempt 1/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 7
# Conditions not met for val. Changing seed to 97912 and retrying... (Attempt 2/2000)
# val set for label Consolidation does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 97913 and retrying... (Attempt 3/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 5
# Conditions not met for val. Changing seed to 97914 and retrying... (Attempt 4/2000)
# val set for label Mass/Nodule does not meet age balance. Old: 0, Young: 14
# Conditions not met for val. Changing seed to 97915 and retrying... (Attempt 5/2000)
# val set for label Pneumonia does not meet age balance. Old: 0, Young: 24
# Conditions not met for val. Changing seed to 97916 and retrying... (Attempt 6/2000)
# val set for label Cardiomegaly does not meet age balance. Old: 0, Young: 8
# Conditions not met for val. Changing seed to 97917 and retrying... (Attempt 7/2000)
# Conditions met for val with seed 97917.
# Conditions met for val with seed 97910.
# Conditions met for train with seed 97910.
# Conditions met for train with seed 97910.
# Conditions met for val with seed 97910.
# Conditions met for val with seed 97910.
# Conditions met for train with seed 97910.
# Conditions met for train with seed 97910.
# Conditions met for val with seed 97910.
# Skipping val assignment for F as the ratio is 0.
# Conditions met for train with seed 97910.
# Skipping train assignment for F as the ratio is 0.

# %%
# Loop through each ratio and print the diagnostic label counts for test, val, and train sets
for seed_idx, seed in enumerate(predefined_seeds):
    for ratio_idx, (male_ratio, female_ratio) in enumerate(ratios):
        dataset_key = f'df_ratio_{male_ratio}_{female_ratio}_seed_{seed}'
        print(f"\nRatio {male_ratio}:{female_ratio}, Seed {seed}\n")
        
        # Print counts for test
        print_label_counts(dfs[dataset_key], 'test')
        
        # Print counts for validation set
        print_label_counts(dfs[dataset_key], 'val')
        
        # Print counts for training set
        print_label_counts(dfs[dataset_key], 'train')
# Out:
# Ratio 0:100, Seed 2358
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      12.0
# Consolidation     13.0
# Infiltration     115.0
# Mass/Nodule       43.0
# Pneumonia         63.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     105.0
# Consolidation    166.0
# Infiltration     872.0
# Mass/Nodule      281.0
# Pneumonia        301.0
# dtype: float64
#
# Ratio 25:75, Seed 2358
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      3.0
# Consolidation     3.0
# Infiltration     31.0
# Mass/Nodule       9.0
# Pneumonia        18.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      6.0
# Consolidation     9.0
# Infiltration     87.0
# Mass/Nodule      28.0
# Pneumonia        35.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      24.0
# Consolidation     35.0
# Infiltration     241.0
# Mass/Nodule       70.0
# Pneumonia         89.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      73.0
# Consolidation    136.0
# Infiltration     657.0
# Mass/Nodule      209.0
# Pneumonia        256.0
# dtype: float64
#
# Ratio 50:50, Seed 2358
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      9.0
# Consolidation    13.0
# Infiltration     53.0
# Mass/Nodule      16.0
# Pneumonia        34.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      8.0
# Consolidation     6.0
# Infiltration     56.0
# Mass/Nodule      17.0
# Pneumonia        29.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      78.0
# Consolidation     62.0
# Infiltration     435.0
# Mass/Nodule      132.0
# Pneumonia        153.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      61.0
# Consolidation     82.0
# Infiltration     435.0
# Mass/Nodule      145.0
# Pneumonia        145.0
# dtype: float64
#
# Ratio 75:25, Seed 2358
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     11.0
# Consolidation    16.0
# Infiltration     81.0
# Mass/Nodule      26.0
# Pneumonia        49.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      3.0
# Consolidation     3.0
# Infiltration     24.0
# Mass/Nodule      11.0
# Pneumonia        11.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     126.0
# Consolidation    109.0
# Infiltration     658.0
# Mass/Nodule      205.0
# Pneumonia        261.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      35.0
# Consolidation     43.0
# Infiltration     221.0
# Mass/Nodule       53.0
# Pneumonia         94.0
# dtype: float64
#
# Ratio 100:0, Seed 2358
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      13.0
# Consolidation     23.0
# Infiltration     105.0
# Mass/Nodule       41.0
# Pneumonia         60.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     155.0
# Consolidation    152.0
# Infiltration     862.0
# Mass/Nodule      270.0
# Pneumonia        339.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 4563
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      15.0
# Consolidation     20.0
# Infiltration     107.0
# Mass/Nodule       41.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     104.0
# Consolidation    159.0
# Infiltration     877.0
# Mass/Nodule      284.0
# Pneumonia        305.0
# dtype: float64
#
# Ratio 25:75, Seed 4563
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      4.0
# Consolidation     7.0
# Infiltration     26.0
# Mass/Nodule       9.0
# Pneumonia        19.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     11.0
# Consolidation    15.0
# Infiltration     81.0
# Mass/Nodule      34.0
# Pneumonia        45.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      26.0
# Consolidation     33.0
# Infiltration     217.0
# Mass/Nodule       72.0
# Pneumonia        110.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      77.0
# Consolidation    130.0
# Infiltration     656.0
# Mass/Nodule      207.0
# Pneumonia        223.0
# dtype: float64
#
# Ratio 50:50, Seed 4563
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      9.0
# Consolidation     6.0
# Infiltration     52.0
# Mass/Nodule      24.0
# Pneumonia        30.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      7.0
# Consolidation    12.0
# Infiltration     50.0
# Mass/Nodule      26.0
# Pneumonia        32.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      45.0
# Consolidation     65.0
# Infiltration     465.0
# Mass/Nodule      137.0
# Pneumonia        179.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      40.0
# Consolidation     80.0
# Infiltration     445.0
# Mass/Nodule      137.0
# Pneumonia        157.0
# dtype: float64
#
# Ratio 75:25, Seed 4563
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     14.0
# Consolidation     6.0
# Infiltration     80.0
# Mass/Nodule      29.0
# Pneumonia        41.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      5.0
# Consolidation     7.0
# Infiltration     26.0
# Mass/Nodule      10.0
# Pneumonia        15.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      74.0
# Consolidation    135.0
# Infiltration     659.0
# Mass/Nodule      235.0
# Pneumonia        233.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      21.0
# Consolidation     46.0
# Infiltration     218.0
# Mass/Nodule       69.0
# Pneumonia         87.0
# dtype: float64
#
# Ratio 100:0, Seed 4563
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      20.0
# Consolidation     15.0
# Infiltration     112.0
# Mass/Nodule       38.0
# Pneumonia         54.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     107.0
# Consolidation    166.0
# Infiltration     909.0
# Mass/Nodule      273.0
# Pneumonia        329.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 7894
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      11.0
# Consolidation     14.0
# Infiltration     111.0
# Mass/Nodule       40.0
# Pneumonia         55.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     107.0
# Consolidation    165.0
# Infiltration     871.0
# Mass/Nodule      287.0
# Pneumonia        307.0
# dtype: float64
#
# Ratio 25:75, Seed 7894
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      5.0
# Consolidation     5.0
# Infiltration     21.0
# Mass/Nodule      13.0
# Pneumonia        16.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      9.0
# Consolidation     9.0
# Infiltration     84.0
# Mass/Nodule      27.0
# Pneumonia        40.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      55.0
# Consolidation     47.0
# Infiltration     210.0
# Mass/Nodule       65.0
# Pneumonia         76.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      76.0
# Consolidation    122.0
# Infiltration     663.0
# Mass/Nodule      220.0
# Pneumonia        217.0
# dtype: float64
#
# Ratio 50:50, Seed 7894
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      9.0
# Consolidation    10.0
# Infiltration     49.0
# Mass/Nodule      22.0
# Pneumonia        28.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      3.0
# Consolidation    11.0
# Infiltration     47.0
# Mass/Nodule      21.0
# Pneumonia        26.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      56.0
# Consolidation     92.0
# Infiltration     448.0
# Mass/Nodule      129.0
# Pneumonia        151.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      52.0
# Consolidation     79.0
# Infiltration     434.0
# Mass/Nodule      152.0
# Pneumonia        168.0
# dtype: float64
#
# Ratio 75:25, Seed 7894
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     15.0
# Consolidation    13.0
# Infiltration     76.0
# Mass/Nodule      30.0
# Pneumonia        41.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      6.0
# Consolidation     6.0
# Infiltration     28.0
# Mass/Nodule       8.0
# Pneumonia        12.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      83.0
# Consolidation    106.0
# Infiltration     678.0
# Mass/Nodule      200.0
# Pneumonia        280.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      27.0
# Consolidation     30.0
# Infiltration     233.0
# Mass/Nodule       66.0
# Pneumonia         80.0
# dtype: float64
#
# Ratio 100:0, Seed 7894
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      21.0
# Consolidation     15.0
# Infiltration     106.0
# Mass/Nodule       37.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     150.0
# Consolidation    176.0
# Infiltration     873.0
# Mass/Nodule      263.0
# Pneumonia        354.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 13289
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      17.0
# Consolidation     18.0
# Infiltration     104.0
# Mass/Nodule       33.0
# Pneumonia         55.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     102.0
# Consolidation    160.0
# Infiltration     877.0
# Mass/Nodule      288.0
# Pneumonia        310.0
# dtype: float64
#
# Ratio 25:75, Seed 13289
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      3.0
# Consolidation     5.0
# Infiltration     26.0
# Mass/Nodule       8.0
# Pneumonia        18.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     12.0
# Consolidation    17.0
# Infiltration     72.0
# Mass/Nodule      28.0
# Pneumonia        45.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      33.0
# Consolidation     46.0
# Infiltration     216.0
# Mass/Nodule       64.0
# Pneumonia         81.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      72.0
# Consolidation    111.0
# Infiltration     657.0
# Mass/Nodule      227.0
# Pneumonia        239.0
# dtype: float64
#
# Ratio 50:50, Seed 13289
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      9.0
# Consolidation     8.0
# Infiltration     56.0
# Mass/Nodule      16.0
# Pneumonia        29.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      8.0
# Consolidation    10.0
# Infiltration     50.0
# Mass/Nodule      21.0
# Pneumonia        26.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      86.0
# Consolidation     76.0
# Infiltration     442.0
# Mass/Nodule      120.0
# Pneumonia        167.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      54.0
# Consolidation     83.0
# Infiltration     455.0
# Mass/Nodule      111.0
# Pneumonia        172.0
# dtype: float64
#
# Ratio 75:25, Seed 13289
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     12.0
# Consolidation    12.0
# Infiltration     81.0
# Mass/Nodule      30.0
# Pneumonia        45.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      2.0
# Consolidation     5.0
# Infiltration     30.0
# Mass/Nodule       4.0
# Pneumonia        12.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      91.0
# Consolidation    106.0
# Infiltration     664.0
# Mass/Nodule      205.0
# Pneumonia        267.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      27.0
# Consolidation     26.0
# Infiltration     215.0
# Mass/Nodule       80.0
# Pneumonia         79.0
# dtype: float64
#
# Ratio 100:0, Seed 13289
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      16.0
# Consolidation     19.0
# Infiltration     100.0
# Mass/Nodule       38.0
# Pneumonia         62.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     137.0
# Consolidation    185.0
# Infiltration     851.0
# Mass/Nodule      274.0
# Pneumonia        353.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 15892
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      12.0
# Consolidation     20.0
# Infiltration     109.0
# Mass/Nodule       42.0
# Pneumonia         65.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     107.0
# Consolidation    154.0
# Infiltration     878.0
# Mass/Nodule      284.0
# Pneumonia        298.0
# dtype: float64
#
# Ratio 25:75, Seed 15892
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      6.0
# Consolidation     5.0
# Infiltration     26.0
# Mass/Nodule       5.0
# Pneumonia         8.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      8.0
# Consolidation    16.0
# Infiltration     86.0
# Mass/Nodule      30.0
# Pneumonia        48.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      27.0
# Consolidation     57.0
# Infiltration     223.0
# Mass/Nodule       60.0
# Pneumonia         78.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      83.0
# Consolidation    124.0
# Infiltration     666.0
# Mass/Nodule      190.0
# Pneumonia        226.0
# dtype: float64
#
# Ratio 50:50, Seed 15892
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      8.0
# Consolidation     6.0
# Infiltration     55.0
# Mass/Nodule      22.0
# Pneumonia        35.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      9.0
# Consolidation     8.0
# Infiltration     59.0
# Mass/Nodule      14.0
# Pneumonia        21.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      64.0
# Consolidation     93.0
# Infiltration     431.0
# Mass/Nodule      135.0
# Pneumonia        149.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      48.0
# Consolidation     72.0
# Infiltration     431.0
# Mass/Nodule      169.0
# Pneumonia        164.0
# dtype: float64
#
# Ratio 75:25, Seed 15892
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     16.0
# Consolidation     8.0
# Infiltration     80.0
# Mass/Nodule      30.0
# Pneumonia        32.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      9.0
# Consolidation     4.0
# Infiltration     30.0
# Mass/Nodule       3.0
# Pneumonia        11.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      77.0
# Consolidation    138.0
# Infiltration     671.0
# Mass/Nodule      204.0
# Pneumonia        254.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      21.0
# Consolidation     45.0
# Infiltration     226.0
# Mass/Nodule       64.0
# Pneumonia         90.0
# dtype: float64
#
# Ratio 100:0, Seed 15892
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      15.0
# Consolidation     11.0
# Infiltration     119.0
# Mass/Nodule       35.0
# Pneumonia         63.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     101.0
# Consolidation    182.0
# Infiltration     880.0
# Mass/Nodule      290.0
# Pneumonia        337.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 19756
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      17.0
# Consolidation     15.0
# Infiltration     109.0
# Mass/Nodule       41.0
# Pneumonia         60.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      99.0
# Consolidation    164.0
# Infiltration     879.0
# Mass/Nodule      282.0
# Pneumonia        303.0
# dtype: float64
#
# Ratio 25:75, Seed 19756
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      3.0
# Consolidation     3.0
# Infiltration     28.0
# Mass/Nodule       9.0
# Pneumonia        10.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      8.0
# Consolidation    14.0
# Infiltration     80.0
# Mass/Nodule      28.0
# Pneumonia        36.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      32.0
# Consolidation     37.0
# Infiltration     226.0
# Mass/Nodule       66.0
# Pneumonia         87.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      86.0
# Consolidation    103.0
# Infiltration     658.0
# Mass/Nodule      232.0
# Pneumonia        238.0
# dtype: float64
#
# Ratio 50:50, Seed 19756
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      5.0
# Consolidation     5.0
# Infiltration     56.0
# Mass/Nodule      20.0
# Pneumonia        32.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      9.0
# Consolidation     4.0
# Infiltration     58.0
# Mass/Nodule      20.0
# Pneumonia        21.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      73.0
# Consolidation     88.0
# Infiltration     435.0
# Mass/Nodule      148.0
# Pneumonia        150.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      43.0
# Consolidation     71.0
# Infiltration     432.0
# Mass/Nodule      162.0
# Pneumonia        170.0
# dtype: float64
#
# Ratio 75:25, Seed 19756
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     10.0
# Consolidation    10.0
# Infiltration     81.0
# Mass/Nodule      34.0
# Pneumonia        47.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      4.0
# Consolidation     3.0
# Infiltration     26.0
# Mass/Nodule      10.0
# Pneumonia        13.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      88.0
# Consolidation    132.0
# Infiltration     641.0
# Mass/Nodule      231.0
# Pneumonia        281.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      21.0
# Consolidation     30.0
# Infiltration     218.0
# Mass/Nodule       73.0
# Pneumonia         77.0
# dtype: float64
#
# Ratio 100:0, Seed 19756
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     15.0
# Infiltration     105.0
# Mass/Nodule       44.0
# Pneumonia         61.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     134.0
# Consolidation    190.0
# Infiltration     862.0
# Mass/Nodule      278.0
# Pneumonia        308.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 23890
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     17.0
# Consolidation    18.0
# Infiltration     97.0
# Mass/Nodule      43.0
# Pneumonia        68.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     101.0
# Consolidation    161.0
# Infiltration     888.0
# Mass/Nodule      281.0
# Pneumonia        294.0
# dtype: float64
#
# Ratio 25:75, Seed 23890
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      5.0
# Consolidation     5.0
# Infiltration     22.0
# Mass/Nodule      13.0
# Pneumonia        16.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     15.0
# Consolidation    15.0
# Infiltration     71.0
# Mass/Nodule      32.0
# Pneumonia        50.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      15.0
# Consolidation     46.0
# Infiltration     236.0
# Mass/Nodule       69.0
# Pneumonia         82.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      81.0
# Consolidation    126.0
# Infiltration     666.0
# Mass/Nodule      200.0
# Pneumonia        241.0
# dtype: float64
#
# Ratio 50:50, Seed 23890
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     10.0
# Consolidation     6.0
# Infiltration     57.0
# Mass/Nodule      15.0
# Pneumonia        25.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     13.0
# Consolidation     9.0
# Infiltration     45.0
# Mass/Nodule      22.0
# Pneumonia        31.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      76.0
# Consolidation     69.0
# Infiltration     450.0
# Mass/Nodule      129.0
# Pneumonia        175.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      55.0
# Consolidation     73.0
# Infiltration     443.0
# Mass/Nodule      133.0
# Pneumonia        143.0
# dtype: float64
#
# Ratio 75:25, Seed 23890
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     12.0
# Consolidation    10.0
# Infiltration     86.0
# Mass/Nodule      25.0
# Pneumonia        40.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      2.0
# Consolidation     2.0
# Infiltration     31.0
# Mass/Nodule       6.0
# Pneumonia        11.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      89.0
# Consolidation    138.0
# Infiltration     663.0
# Mass/Nodule      202.0
# Pneumonia        249.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      15.0
# Consolidation     43.0
# Infiltration     227.0
# Mass/Nodule       74.0
# Pneumonia         73.0
# dtype: float64
#
# Ratio 100:0, Seed 23890
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     12.0
# Infiltration     115.0
# Mass/Nodule       36.0
# Pneumonia         54.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     137.0
# Consolidation    176.0
# Infiltration     836.0
# Mass/Nodule      278.0
# Pneumonia        340.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 27456
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      14.0
# Consolidation     18.0
# Infiltration     103.0
# Mass/Nodule       44.0
# Pneumonia         61.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     102.0
# Consolidation    159.0
# Infiltration     884.0
# Mass/Nodule      283.0
# Pneumonia        302.0
# dtype: float64
#
# Ratio 25:75, Seed 27456
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      4.0
# Consolidation     3.0
# Infiltration     34.0
# Mass/Nodule       6.0
# Pneumonia         9.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     12.0
# Consolidation    14.0
# Infiltration     72.0
# Mass/Nodule      33.0
# Pneumonia        45.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      29.0
# Consolidation     30.0
# Infiltration     215.0
# Mass/Nodule       85.0
# Pneumonia         87.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      78.0
# Consolidation    103.0
# Infiltration     666.0
# Mass/Nodule      202.0
# Pneumonia        233.0
# dtype: float64
#
# Ratio 50:50, Seed 27456
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      5.0
# Consolidation     6.0
# Infiltration     67.0
# Mass/Nodule      14.0
# Pneumonia        23.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     11.0
# Consolidation    10.0
# Infiltration     49.0
# Mass/Nodule      16.0
# Pneumonia        32.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      73.0
# Consolidation    101.0
# Infiltration     437.0
# Mass/Nodule      133.0
# Pneumonia        166.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      46.0
# Consolidation     83.0
# Infiltration     433.0
# Mass/Nodule      139.0
# Pneumonia        160.0
# dtype: float64
#
# Ratio 75:25, Seed 27456
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     21.0
# Consolidation    14.0
# Infiltration     83.0
# Mass/Nodule      27.0
# Pneumonia        51.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      7.0
# Consolidation     4.0
# Infiltration     27.0
# Mass/Nodule       7.0
# Pneumonia        16.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     105.0
# Consolidation    129.0
# Infiltration     671.0
# Mass/Nodule      197.0
# Pneumonia        237.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      22.0
# Consolidation     23.0
# Infiltration     219.0
# Mass/Nodule       81.0
# Pneumonia         72.0
# dtype: float64
#
# Ratio 100:0, Seed 27456
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      15.0
# Consolidation     17.0
# Infiltration     117.0
# Mass/Nodule       37.0
# Pneumonia         58.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     116.0
# Consolidation    177.0
# Infiltration     875.0
# Mass/Nodule      290.0
# Pneumonia        335.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 30890
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      17.0
# Consolidation     10.0
# Infiltration     113.0
# Mass/Nodule       40.0
# Pneumonia         56.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     101.0
# Consolidation    167.0
# Infiltration     871.0
# Mass/Nodule      288.0
# Pneumonia        307.0
# dtype: float64
#
# Ratio 25:75, Seed 30890
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      4.0
# Consolidation     2.0
# Infiltration     28.0
# Mass/Nodule       8.0
# Pneumonia        13.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     12.0
# Consolidation    12.0
# Infiltration     80.0
# Mass/Nodule      24.0
# Pneumonia        48.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      26.0
# Consolidation     29.0
# Infiltration     225.0
# Mass/Nodule       77.0
# Pneumonia         88.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      76.0
# Consolidation    124.0
# Infiltration     668.0
# Mass/Nodule      218.0
# Pneumonia        205.0
# dtype: float64
#
# Ratio 50:50, Seed 30890
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      4.0
# Consolidation     9.0
# Infiltration     55.0
# Mass/Nodule      22.0
# Pneumonia        29.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      7.0
# Consolidation     6.0
# Infiltration     54.0
# Mass/Nodule      16.0
# Pneumonia        32.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      53.0
# Consolidation     80.0
# Infiltration     433.0
# Mass/Nodule      169.0
# Pneumonia        173.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      50.0
# Consolidation     99.0
# Infiltration     439.0
# Mass/Nodule      142.0
# Pneumonia        142.0
# dtype: float64
#
# Ratio 75:25, Seed 30890
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     11.0
# Consolidation     9.0
# Infiltration     89.0
# Mass/Nodule      20.0
# Pneumonia        45.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      4.0
# Consolidation     3.0
# Infiltration     29.0
# Mass/Nodule       8.0
# Pneumonia        11.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      74.0
# Consolidation    138.0
# Infiltration     647.0
# Mass/Nodule      218.0
# Pneumonia        286.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      18.0
# Consolidation     57.0
# Infiltration     228.0
# Mass/Nodule       55.0
# Pneumonia         80.0
# dtype: float64
#
# Ratio 100:0, Seed 30890
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      11.0
# Consolidation     19.0
# Infiltration     100.0
# Mass/Nodule       50.0
# Pneumonia         62.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     142.0
# Consolidation    157.0
# Infiltration     885.0
# Mass/Nodule      264.0
# Pneumonia        342.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 34905
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      12.0
# Consolidation     18.0
# Infiltration     115.0
# Mass/Nodule       33.0
# Pneumonia         45.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     107.0
# Consolidation    160.0
# Infiltration     868.0
# Mass/Nodule      293.0
# Pneumonia        316.0
# dtype: float64
#
# Ratio 25:75, Seed 34905
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      8.0
# Consolidation     3.0
# Infiltration     26.0
# Mass/Nodule       7.0
# Pneumonia        11.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     11.0
# Consolidation    13.0
# Infiltration     84.0
# Mass/Nodule      26.0
# Pneumonia        36.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      28.0
# Consolidation     43.0
# Infiltration     222.0
# Mass/Nodule       71.0
# Pneumonia         78.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      82.0
# Consolidation    135.0
# Infiltration     652.0
# Mass/Nodule      203.0
# Pneumonia        244.0
# dtype: float64
#
# Ratio 50:50, Seed 34905
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      8.0
# Consolidation     8.0
# Infiltration     56.0
# Mass/Nodule      17.0
# Pneumonia        26.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     10.0
# Consolidation    10.0
# Infiltration     55.0
# Mass/Nodule      16.0
# Pneumonia        24.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      50.0
# Consolidation    105.0
# ...
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      15.0
# Consolidation     14.0
# Infiltration     117.0
# Mass/Nodule       39.0
# Pneumonia         61.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     120.0
# Consolidation    172.0
# Infiltration     873.0
# Mass/Nodule      277.0
# Pneumonia        355.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 89357
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      16.0
# Consolidation     16.0
# Infiltration     106.0
# Mass/Nodule       34.0
# Pneumonia         48.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     103.0
# Consolidation    161.0
# Infiltration     875.0
# Mass/Nodule      294.0
# Pneumonia        317.0
# dtype: float64
#
# Ratio 25:75, Seed 89357
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      6.0
# Consolidation     3.0
# Infiltration     26.0
# Mass/Nodule       9.0
# Pneumonia        14.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     12.0
# Consolidation    10.0
# Infiltration     80.0
# Mass/Nodule      29.0
# Pneumonia        33.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      28.0
# Consolidation     49.0
# Infiltration     216.0
# Mass/Nodule       77.0
# Pneumonia         95.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      78.0
# Consolidation    117.0
# Infiltration     661.0
# Mass/Nodule      215.0
# Pneumonia        243.0
# dtype: float64
#
# Ratio 50:50, Seed 89357
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     12.0
# Consolidation     6.0
# Infiltration     49.0
# Mass/Nodule      16.0
# Pneumonia        19.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      9.0
# Consolidation     7.0
# Infiltration     50.0
# Mass/Nodule      17.0
# Pneumonia        29.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      81.0
# Consolidation     82.0
# Infiltration     432.0
# Mass/Nodule      135.0
# Pneumonia        161.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      50.0
# Consolidation     94.0
# Infiltration     435.0
# Mass/Nodule      146.0
# Pneumonia        148.0
# dtype: float64
#
# Ratio 75:25, Seed 89357
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     10.0
# Consolidation    18.0
# Infiltration     78.0
# Mass/Nodule      32.0
# Pneumonia        50.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      6.0
# Consolidation     7.0
# Infiltration     27.0
# Mass/Nodule       9.0
# Pneumonia        17.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     104.0
# Consolidation    122.0
# Infiltration     644.0
# Mass/Nodule      214.0
# Pneumonia        247.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      21.0
# Consolidation     40.0
# Infiltration     218.0
# Mass/Nodule       72.0
# Pneumonia         89.0
# dtype: float64
#
# Ratio 100:0, Seed 89357
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly       7.0
# Consolidation     19.0
# Infiltration     114.0
# Mass/Nodule       36.0
# Pneumonia         57.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     123.0
# Consolidation    167.0
# Infiltration     890.0
# Mass/Nodule      274.0
# Pneumonia        332.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 93450
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      13.0
# Consolidation     11.0
# Infiltration     120.0
# Mass/Nodule       40.0
# Pneumonia         55.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     104.0
# Consolidation    168.0
# Infiltration     865.0
# Mass/Nodule      286.0
# Pneumonia        308.0
# dtype: float64
#
# Ratio 25:75, Seed 93450
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      4.0
# Consolidation     5.0
# Infiltration     25.0
# Mass/Nodule       9.0
# Pneumonia        11.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     12.0
# Consolidation    11.0
# Infiltration     86.0
# Mass/Nodule      30.0
# Pneumonia        43.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      26.0
# Consolidation     46.0
# Infiltration     224.0
# Mass/Nodule       71.0
# Pneumonia         77.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      73.0
# Consolidation    102.0
# Infiltration     649.0
# Mass/Nodule      238.0
# Pneumonia        231.0
# dtype: float64
#
# Ratio 50:50, Seed 93450
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     10.0
# Consolidation     9.0
# Infiltration     54.0
# Mass/Nodule      17.0
# Pneumonia        25.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      8.0
# Consolidation     9.0
# Infiltration     59.0
# Mass/Nodule      19.0
# Pneumonia        31.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      59.0
# Consolidation     72.0
# Infiltration     432.0
# Mass/Nodule      142.0
# Pneumonia        179.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      52.0
# Consolidation     76.0
# Infiltration     444.0
# Mass/Nodule      136.0
# Pneumonia        156.0
# dtype: float64
#
# Ratio 75:25, Seed 93450
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     17.0
# Consolidation    12.0
# Infiltration     77.0
# Mass/Nodule      32.0
# Pneumonia        42.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      4.0
# Consolidation     4.0
# Infiltration     30.0
# Mass/Nodule      12.0
# Pneumonia        15.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      89.0
# Consolidation    133.0
# Infiltration     677.0
# Mass/Nodule      185.0
# Pneumonia        256.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      32.0
# Consolidation     46.0
# Infiltration     223.0
# Mass/Nodule       58.0
# Pneumonia         69.0
# dtype: float64
#
# Ratio 100:0, Seed 93450
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      19.0
# Consolidation     17.0
# Infiltration     105.0
# Mass/Nodule       42.0
# Pneumonia         56.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     130.0
# Consolidation    171.0
# Infiltration     867.0
# Mass/Nodule      262.0
# Pneumonia        327.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 97910
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      10.0
# Consolidation     13.0
# Infiltration     122.0
# Mass/Nodule       34.0
# Pneumonia         58.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     109.0
# Consolidation    166.0
# Infiltration     860.0
# Mass/Nodule      291.0
# Pneumonia        306.0
# dtype: float64
#
# Ratio 25:75, Seed 97910
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      5.0
# Consolidation     3.0
# Infiltration     23.0
# Mass/Nodule      15.0
# Pneumonia        20.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      6.0
# Consolidation    11.0
# Infiltration     89.0
# Mass/Nodule      26.0
# Pneumonia        43.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      26.0
# Consolidation     37.0
# Infiltration     230.0
# Mass/Nodule       67.0
# Pneumonia         91.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      69.0
# Consolidation    135.0
# Infiltration     657.0
# Mass/Nodule      221.0
# Pneumonia        217.0
# dtype: float64
#
# Ratio 50:50, Seed 97910
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      6.0
# Consolidation     9.0
# Infiltration     50.0
# Mass/Nodule      25.0
# Pneumonia        26.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      3.0
# Consolidation     7.0
# Infiltration     61.0
# Mass/Nodule      18.0
# Pneumonia        30.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      58.0
# Consolidation     74.0
# Infiltration     436.0
# Mass/Nodule      144.0
# Pneumonia        172.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      49.0
# Consolidation     74.0
# Infiltration     431.0
# Mass/Nodule      155.0
# Pneumonia        146.0
# dtype: float64
#
# Ratio 75:25, Seed 97910
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      7.0
# Consolidation    14.0
# Infiltration     80.0
# Mass/Nodule      33.0
# Pneumonia        48.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      3.0
# Consolidation     5.0
# Infiltration     28.0
# Mass/Nodule      11.0
# Pneumonia        16.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly      81.0
# Consolidation    116.0
# Infiltration     660.0
# Mass/Nodule      227.0
# Pneumonia        244.0
# dtype: float64
# Gender Group: F
# Cardiomegaly      39.0
# Consolidation     31.0
# Infiltration     223.0
# Mass/Nodule       64.0
# Pneumonia         77.0
# dtype: float64
#
# Ratio 100:0, Seed 97910
#
#
# Diagnostic Label Counts for test Set:
# Gender Group: M
# Cardiomegaly      14.0
# Consolidation     17.0
# Infiltration     102.0
# Mass/Nodule       42.0
# Pneumonia         53.0
# dtype: float64
# Gender Group: F
# Cardiomegaly       8.0
# Consolidation     18.0
# Infiltration     121.0
# Mass/Nodule       29.0
# Pneumonia         59.0
# dtype: float64
#
# Diagnostic Label Counts for val Set:
# Gender Group: M
# Cardiomegaly      10.0
# Consolidation     20.0
# Infiltration     109.0
# Mass/Nodule       44.0
# Pneumonia         65.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Gender Group: M
# Cardiomegaly     136.0
# Consolidation    178.0
# Infiltration     886.0
# Mass/Nodule      268.0
# Pneumonia        316.0
# dtype: float64
# Gender Group: F
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64

# %%
import pandas as pd
fives = ['0', '25', '50', '75', '100']
for seed in predefined_seeds:
    for five in fives:
        # Load the data
        file_path = parent + f'no_finding/metadata/aggregate_sex_nf/aggregate_sex_nf_seed_{seed}/sex_{five}_seed_{seed}.csv' 
        data = pd.read_csv(file_path)

        # Define the disease labels for summing up their counts
        disease_labels = ['No Finding', 'Cardiomegaly', 'Consolidation', 'Infiltration', 'Mass/Nodule', 'Pneumonia']

        # Group the data by 'Age Group' and 'Set', sum the counts for each disease label, and count the total images
        grouped_counts_diseases = data.groupby(['Patient Gender', 'Set']).agg(
            {**{label: 'sum' for label in disease_labels}, 'Image Index': 'count'}).reset_index()

        # Rename 'Image Index' column to 'Total Images'
        grouped_counts_diseases.rename(columns={'Image Index': 'Total Images'}, inplace=True)

        # Export to CSV
        output_file_path = parent + f'no_finding/experiment/metadata_count/seed{seed}/sex_{five}_seed_{seed}.csv.csv'  # Specify your desired output file name and path
        grouped_counts_diseases.to_csv(output_file_path, index=False)

        print(f"Data exported successfully to {output_file_path}")
# Out:
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed2358/sex_0_seed_2358.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed2358/sex_25_seed_2358.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed2358/sex_50_seed_2358.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed2358/sex_75_seed_2358.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed2358/sex_100_seed_2358.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed4563/sex_0_seed_4563.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed4563/sex_25_seed_4563.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed4563/sex_50_seed_4563.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed4563/sex_75_seed_4563.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed4563/sex_100_seed_4563.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed7894/sex_0_seed_7894.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed7894/sex_25_seed_7894.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed7894/sex_50_seed_7894.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed7894/sex_75_seed_7894.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed7894/sex_100_seed_7894.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed13289/sex_0_seed_13289.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed13289/sex_25_seed_13289.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed13289/sex_50_seed_13289.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed13289/sex_75_seed_13289.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed13289/sex_100_seed_13289.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed15892/sex_0_seed_15892.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed15892/sex_25_seed_15892.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed15892/sex_50_seed_15892.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed15892/sex_75_seed_15892.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed15892/sex_100_seed_15892.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed19756/sex_0_seed_19756.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed19756/sex_25_seed_19756.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed19756/sex_50_seed_19756.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed19756/sex_75_seed_19756.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed19756/sex_100_seed_19756.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed23890/sex_0_seed_23890.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed23890/sex_25_seed_23890.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed23890/sex_50_seed_23890.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed23890/sex_75_seed_23890.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed23890/sex_100_seed_23890.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed27456/sex_0_seed_27456.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed27456/sex_25_seed_27456.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed27456/sex_50_seed_27456.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed27456/sex_75_seed_27456.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed27456/sex_100_seed_27456.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed30890/sex_0_seed_30890.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed30890/sex_25_seed_30890.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed30890/sex_50_seed_30890.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed30890/sex_75_seed_30890.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed30890/sex_100_seed_30890.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed34905/sex_0_seed_34905.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed34905/sex_25_seed_34905.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed34905/sex_50_seed_34905.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed34905/sex_75_seed_34905.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed34905/sex_100_seed_34905.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed38764/sex_0_seed_38764.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed38764/sex_25_seed_38764.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed38764/sex_50_seed_38764.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed38764/sex_75_seed_38764.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed38764/sex_100_seed_38764.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed42136/sex_0_seed_42136.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed42136/sex_25_seed_42136.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed42136/sex_50_seed_42136.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed42136/sex_75_seed_42136.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed42136/sex_100_seed_42136.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed46578/sex_0_seed_46578.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed46578/sex_25_seed_46578.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed46578/sex_50_seed_46578.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed46578/sex_75_seed_46578.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed46578/sex_100_seed_46578.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed50349/sex_0_seed_50349.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed50349/sex_25_seed_50349.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed50349/sex_50_seed_50349.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed50349/sex_75_seed_50349.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed50349/sex_100_seed_50349.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed54892/sex_0_seed_54892.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed54892/sex_25_seed_54892.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed54892/sex_50_seed_54892.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed54892/sex_75_seed_54892.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed54892/sex_100_seed_54892.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed59871/sex_0_seed_59871.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed59871/sex_25_seed_59871.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed59871/sex_50_seed_59871.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed59871/sex_75_seed_59871.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed59871/sex_100_seed_59871.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed63912/sex_0_seed_63912.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed63912/sex_25_seed_63912.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed63912/sex_50_seed_63912.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed63912/sex_75_seed_63912.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed63912/sex_100_seed_63912.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed68354/sex_0_seed_68354.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed68354/sex_25_seed_68354.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed68354/sex_50_seed_68354.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed68354/sex_75_seed_68354.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed68354/sex_100_seed_68354.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed72109/sex_0_seed_72109.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed72109/sex_25_seed_72109.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed72109/sex_50_seed_72109.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed72109/sex_75_seed_72109.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed72109/sex_100_seed_72109.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed76845/sex_0_seed_76845.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed76845/sex_25_seed_76845.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed76845/sex_50_seed_76845.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed76845/sex_75_seed_76845.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed76845/sex_100_seed_76845.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed80492/sex_0_seed_80492.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed80492/sex_25_seed_80492.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed80492/sex_50_seed_80492.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed80492/sex_75_seed_80492.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed80492/sex_100_seed_80492.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed84910/sex_0_seed_84910.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed84910/sex_25_seed_84910.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed84910/sex_50_seed_84910.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed84910/sex_75_seed_84910.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed84910/sex_100_seed_84910.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed89357/sex_0_seed_89357.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed89357/sex_25_seed_89357.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed89357/sex_50_seed_89357.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed89357/sex_75_seed_89357.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed89357/sex_100_seed_89357.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed93450/sex_0_seed_93450.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed93450/sex_25_seed_93450.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed93450/sex_50_seed_93450.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed93450/sex_75_seed_93450.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed93450/sex_100_seed_93450.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed97910/sex_0_seed_97910.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed97910/sex_25_seed_97910.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed97910/sex_50_seed_97910.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed97910/sex_75_seed_97910.csv.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed97910/sex_100_seed_97910.csv.csv
