# %%
import pandas as pd
parent = '/home/jkim/research/peds_cxr/'

base = pd.read_csv(parent + 'no_finding/metadata/base_metadata.csv') 

# Filter patient_ids that have both 'Young' and 'Old' in 'Age Group'
# First, identify all patient_ids for each 'Age Group'
young_patient_ids = set(base[base['Age Group'] == 'young']['Patient_id'])
old_patient_ids = set(base[base['Age Group'] == 'old']['Patient_id'])

# Find patient_ids that appear in both sets
common_patient_ids = young_patient_ids.intersection(old_patient_ids)

# Convert to list and sort for presentation
patient_ids_to_check = sorted(list(common_patient_ids))

# Display the sorted list of common patient_ids
print(patient_ids_to_check)
print(len(patient_ids_to_check))
print(base[base['Patient_id'].isin(patient_ids_to_check)]['Age Group'].value_counts())

df1 = base[(base['Patient_id'].isin(patient_ids_to_check)) & (base['Age Group'] == 'young')]
df1.to_csv(parent + 'no_finding/experiment/young_intersect.csv', index=False)
# Drop rows where 'Patient_id' is in the specified list AND 'Age Group' is 'young'
df = base.drop(base[(base['Patient_id'].isin(patient_ids_to_check)) & (base['Age Group'] == 'young')].index)

# Create Positive Label adn Patient Patient column
positive_conditions = ['Pneumonia', 'Cardiomegaly', 'Consolidation', 'Infiltration', 'Mass/Nodule'] 
df['Positive_Label'] = df[positive_conditions].any(axis=1).astype(int)
positive_patients = df[df['Positive_Label'] == 1]['Patient_id'].unique()
df['Positive_Patient'] = df['Patient_id'].isin(positive_patients).astype(int)

# Save
df.to_csv(parent + 'no_finding/metadata/base_metadata_age.csv', index=False)

# Display the shape of the original and the filtered dataframe to see the number of rows dropped
print("Original DataFrame shape:", base.shape)
print("Filtered DataFrame shape:", df.shape)
# Out:
# ['00002555', '00003074', '00004028', '00004472', '00005065', '00005146', '00005724', '00005834', '00005864', '00006180', '00006294', '00007087', '00010152', '00010360', '00010431', '00010460', '00011689', '00012654', '00014323', '00014352', '00014474', '00015553', '00015996', '00016054', '00016484', '00017538', '00018251', '00018445', '00018458', '00018778', '00019045', '00021571', '00029174']
# 33
# old      85
# young    68
# Name: Age Group, dtype: int64
# Original DataFrame shape: (12924, 14)
# Filtered DataFrame shape: (12856, 14)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

positive_patients_df = df[df['Positive_Patient'] == 1].drop_duplicates(subset='Patient_id')
result = positive_patients_df.groupby(['Age Group', 'Patient Gender']).size().reset_index(name='Number of Positive Patients')
print(result)

negative_patients_df = df[df['Positive_Patient'] == 0].drop_duplicates(subset='Patient_id')
negative_result = negative_patients_df.groupby(['Age Group', 'Patient Gender']).size().reset_index(name='Number of Negative Patients')
print(negative_result)

diagnostic_labels = ['No Finding', 'Cardiomegaly', 'Consolidation', 'Infiltration', 'Mass/Nodule', 'Pneumonia']
grouped_counts = df.groupby(['Age Group', 'Patient Gender'])[diagnostic_labels].sum()
print(grouped_counts)

positive_label_counts = df.groupby(['Age Group', 'Patient Gender'])['Positive_Label'].sum()
print(positive_label_counts)
# Out:
#   Age Group Patient Gender  Number of Positive Patients
# 0       old              F                          213
# 1       old              M                          309
# 2     young              F                          947
# 3     young              M                         1450
#   Age Group Patient Gender  Number of Negative Patients
# 0       old              F                          656
# 1       old              M                          856
# 2     young              F                         2252
# 3     young              M                         3139
#                           No Finding  Cardiomegaly  Consolidation  \
# Age Group Patient Gender
# old       F                     1491            45            105
#           M                     1921            98            165
# young     F                     2288            80             90
#           M                     3177           145            142
#
#                           Infiltration  Mass/Nodule  Pneumonia
# Age Group Patient Gender
# old       F                        394          141         52
#           M                        632          192         67
# young     F                        713          215        370
#           M                       1033          362        606
# Age Group  Patient Gender
# old        F                  605
#            M                  945
# young      F                  964
#            M                 1465
# Name: Positive_Label, dtype: int64

# %%
import pandas as pd
import random
import os

# Load the CSV file
file_path = parent + 'no_finding/metadata/base_metadata_age.csv'
df = pd.read_csv(file_path)

# Predefined seeds to create different splits
predefined_seeds = [2358, 4563, 7894, 13289, 15892, 19756, 23890, 27456, 30890, 34905, 38764, 42136, 46578, 50349, 54892, 59871, 63912, 68354, 72109, 76845, 80492, 84910, 89357, 93450, 97910]

# Define the ratios and diagnostic labels
ratios = [(0, 100), (25, 75), (50, 50), (75, 25), (100, 0)]
diagnostic_labels = ['Cardiomegaly', 'Consolidation', 'Infiltration', 'Mass/Nodule', 'Pneumonia']

# Function to calculate and print diagnostic label counts for each set
def print_label_counts(df, set_name):
    print(f"\nDiagnostic Label Counts for {set_name} Set:")
    for age_group in ['old', 'young']:
        print(f"Age Group: {age_group}")
        df_set = df[(df['Set'].str.contains(set_name)) & (df['Age Group'] == age_group)]
        label_counts = df_set[diagnostic_labels].sum()
        print(label_counts)

# Helper function to assign patients to a given set
def assign_patients_to_set(df, age_group, positive_patient, positive_label, total_count, set_name, seed, max_images_per_patient=None):
    df_age_group = df[(df['Age Group'] == age_group) & (df['Set'] == '')]

    # Filter for patients with specified positive or negative label
    if positive_patient == 1:
        patients = df_age_group[df_age_group['Positive_Patient'] == positive_patient].groupby('Patient_id').filter(lambda x: len(x) <= 3 if max_images_per_patient else True)
    else:
        patients = df_age_group[(df_age_group['Positive_Label'] == positive_label) & (df_age_group['Positive_Patient'] == positive_patient)].groupby('Patient_id').filter(lambda x: len(x) <= 3 if max_images_per_patient else True)

    unique_patients = patients['Patient_id'].unique()
    
    # Shuffle patients
    random.seed(seed)
    random.shuffle(unique_patients)
    
    count = 0  # Track the number of images assigned
    assigned_patients = set()
    
    for patient_id in unique_patients:
        patient_rows = df[df['Patient_id'] == patient_id]
        if positive_patient == 1:
            label_count = patient_rows['Positive_Label'].sum()  # Count positive images
        else:
            label_count = len(patient_rows[patient_rows['Positive_Label'] == positive_label])  # Count negative images

        # Check if adding this patient exceeds the total count limit
        if count + label_count <= total_count:
            df.loc[df['Patient_id'] == patient_id, 'Set'] = set_name  # Assign patient to the set
            count += label_count
            assigned_patients.add(patient_id)  # Keep track of assigned patients

        if count >= total_count:
            break

    return df, assigned_patients

# Function to check if each diagnostic label in each set contains at least 2 male and 2 female images
def check_gender_balance_per_label(df, set_name, min_count):
    for label in diagnostic_labels:
        df_filtered = df[(df['Set'].str.contains(set_name)) & (df['Positive_Label'] == 1) & (df[label] == 1)]
        male_count = df_filtered[df_filtered['Patient Gender'] == 'M'].shape[0]
        female_count = df_filtered[df_filtered['Patient Gender'] == 'F'].shape[0]
        if male_count < min_count or female_count < min_count:
            print(f"{set_name} set for label {label} does not meet gender balance. M: {male_count}, F: {female_count}")
            return False
    return True

# Function to perform assignments with checking conditions and changing seeds if conditions aren't met
def assign_with_conditions(df, age_group, positive_patient, positive_label, total_count, set_name, seed, max_images_per_patient=None, min_count=2, retry_limit=1000):
    # Skip the function entirely if the ratio for this age group is 0
    if (age_group == 'old' and total_count == 0) or (age_group == 'young' and total_count == 0):
        print(f"Skipping {set_name} assignment for {age_group} as the ratio is 0.")
        return df

    retry_count = 0
    while retry_count < retry_limit:  # Retry until conditions are met or retry limit is reached
        df_temp = df[df['Set'] == ''].copy()  # Work with a copy of the original DataFrame

        # Perform the assignment
        df_temp, _ = assign_patients_to_set(df_temp, age_group, positive_patient, positive_label, total_count, set_name, seed, max_images_per_patient)

        # Check if the assigned set meets the gender balance condition per diagnostic label
        if check_gender_balance_per_label(df_temp, set_name, min_count):
            # Only update the original DataFrame where 'Set' is still empty
            df.loc[df_temp.index[df_temp['Set'] == set_name], 'Set'] = set_name
            print(f"Conditions met for {set_name} with seed {seed}, {positive_label}")
            return df
        else:
            retry_count += 1
            # Change to a new random seed
            seed = seed + 1
            print(f"Conditions not met for {set_name}. Changing seed to {seed} and retrying... (Attempt {retry_count}/{retry_limit})")

    # If retry limit is reached, raise an error to stop the code
    error_message = f"Retry limit of {retry_limit} reached for {set_name}. The last seed {seed} did not meet the requirement."
    print(error_message)
    raise RuntimeError(error_message)

# Create the datasets using the new function
dfs = {}  # Dictionary to hold the generated DataFrames

# First, assign the test set (this will remain the same across all splits)
df['Set'] = ''  # Reset the 'Set' column
df = assign_with_conditions(df, 'old', 1, 1, 155, 'test', seed=10, max_images_per_patient=3)
df = assign_with_conditions(df, 'young', 1, 1, 155, 'test', seed=10, max_images_per_patient=3)
df = assign_patients_to_set(df, 'old', 0, 0, 341, 'test', seed=10, max_images_per_patient=3)[0]
df = assign_patients_to_set(df, 'young', 0, 0, 341, 'test', seed=10, max_images_per_patient=3)[0]

print_label_counts(df, 'test')

# Now, iterate over each ratio and seed to create 125 datasets
for seed_idx, seed in enumerate(predefined_seeds):
    for ratio_idx, (old_ratio, young_ratio) in enumerate(ratios):
        print(f'{seed}, old ratio {old_ratio}')
        # Create a copy of the DataFrame with the test set already assigned
        df_copy = df.copy()

        # Store the DataFrame in the dictionary with a key based on the ratio and seed
        dataset_key = f'df_ratio_{old_ratio}_{young_ratio}_seed_{seed}'
        dfs[dataset_key] = df_copy

        # Create validation set (155 positive, 341 negative)
        validation_set_name = 'val'
        dfs[dataset_key] = assign_with_conditions(dfs[dataset_key], 'old', 1, 1, int(155 * (old_ratio / 100)), validation_set_name, seed, max_images_per_patient=3)
        dfs[dataset_key] = assign_with_conditions(dfs[dataset_key], 'young', 1, 1, int(155 * (young_ratio / 100)), validation_set_name, seed, max_images_per_patient=3)
        dfs[dataset_key] = assign_patients_to_set(dfs[dataset_key], 'old', 0, 0, int(341 * (old_ratio / 100)), validation_set_name, seed, max_images_per_patient=3)[0]
        dfs[dataset_key] = assign_patients_to_set(dfs[dataset_key], 'young', 0, 0, int(341 * (young_ratio / 100)), validation_set_name, seed, max_images_per_patient=3)[0]

        # Create training set (1240 positive, 2729 negative)
        training_set_name = 'train'
        dfs[dataset_key] = assign_with_conditions(dfs[dataset_key], 'old', 1, 1, int(1240 * (old_ratio / 100)), training_set_name, seed)
        dfs[dataset_key] = assign_with_conditions(dfs[dataset_key], 'young', 1, 1, int(1240 * (young_ratio / 100)), training_set_name, seed)
        dfs[dataset_key] = assign_patients_to_set(dfs[dataset_key], 'old', 0, 0, int(2729 * (old_ratio / 100)), training_set_name, seed)[0]
        dfs[dataset_key] = assign_patients_to_set(dfs[dataset_key], 'young', 0, 0, int(2729 * (young_ratio / 100)), training_set_name, seed)[0]

        # Save the generated DataFrame to a CSV file
        output_path = os.path.join(parent, f'no_finding/metadata/aggregate_age_nf/aggregate_age_nf_seed_{seed}/age_{old_ratio}_seed_{seed}.csv')
        dfs[dataset_key].to_csv(output_path, index=False)
# Out:
# Conditions met for test with seed 10, 1
# Conditions met for test with seed 10, 1
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
# 2358, old ratio 0
# Skipping val assignment for old as the ratio is 0.
# Conditions met for val with seed 2358, 1
# Skipping train assignment for old as the ratio is 0.
# Conditions met for train with seed 2358, 1
# 2358, old ratio 25
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2359 and retrying... (Attempt 1/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2360 and retrying... (Attempt 2/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2361 and retrying... (Attempt 3/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2362 and retrying... (Attempt 4/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2363 and retrying... (Attempt 5/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2364 and retrying... (Attempt 6/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2365 and retrying... (Attempt 7/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 5
# Conditions not met for val. Changing seed to 2366 and retrying... (Attempt 8/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2367 and retrying... (Attempt 9/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2368 and retrying... (Attempt 10/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2369 and retrying... (Attempt 11/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2370 and retrying... (Attempt 12/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2371 and retrying... (Attempt 13/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2372 and retrying... (Attempt 14/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2373 and retrying... (Attempt 15/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2374 and retrying... (Attempt 16/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2375 and retrying... (Attempt 17/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2376 and retrying... (Attempt 18/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 3
# Conditions not met for val. Changing seed to 2377 and retrying... (Attempt 19/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2378 and retrying... (Attempt 20/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2379 and retrying... (Attempt 21/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 4
# Conditions not met for val. Changing seed to 2380 and retrying... (Attempt 22/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2381 and retrying... (Attempt 23/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2382 and retrying... (Attempt 24/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 2383 and retrying... (Attempt 25/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2384 and retrying... (Attempt 26/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2385 and retrying... (Attempt 27/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2386 and retrying... (Attempt 28/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2387 and retrying... (Attempt 29/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2388 and retrying... (Attempt 30/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2389 and retrying... (Attempt 31/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2390 and retrying... (Attempt 32/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2391 and retrying... (Attempt 33/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2392 and retrying... (Attempt 34/1000)
# val set for label Consolidation does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2393 and retrying... (Attempt 35/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2394 and retrying... (Attempt 36/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2395 and retrying... (Attempt 37/1000)
# val set for label Consolidation does not meet gender balance. M: 4, F: 0
# Conditions not met for val. Changing seed to 2396 and retrying... (Attempt 38/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2397 and retrying... (Attempt 39/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 4
# Conditions not met for val. Changing seed to 2398 and retrying... (Attempt 40/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2399 and retrying... (Attempt 41/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2400 and retrying... (Attempt 42/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2401 and retrying... (Attempt 43/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2402 and retrying... (Attempt 44/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2403 and retrying... (Attempt 45/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2404 and retrying... (Attempt 46/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2405 and retrying... (Attempt 47/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2406 and retrying... (Attempt 48/1000)
# val set for label Consolidation does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 2407 and retrying... (Attempt 49/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2408 and retrying... (Attempt 50/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2409 and retrying... (Attempt 51/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 2410 and retrying... (Attempt 52/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2411 and retrying... (Attempt 53/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 4, F: 1
# Conditions not met for val. Changing seed to 2412 and retrying... (Attempt 54/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 4
# Conditions not met for val. Changing seed to 2413 and retrying... (Attempt 55/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2414 and retrying... (Attempt 56/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 2415 and retrying... (Attempt 57/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2416 and retrying... (Attempt 58/1000)
# val set for label Consolidation does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2417 and retrying... (Attempt 59/1000)
# val set for label Consolidation does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2418 and retrying... (Attempt 60/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2419 and retrying... (Attempt 61/1000)
# val set for label Consolidation does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2420 and retrying... (Attempt 62/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2421 and retrying... (Attempt 63/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2422 and retrying... (Attempt 64/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2423 and retrying... (Attempt 65/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 4
# Conditions not met for val. Changing seed to 2424 and retrying... (Attempt 66/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2425 and retrying... (Attempt 67/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2426 and retrying... (Attempt 68/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2427 and retrying... (Attempt 69/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2428 and retrying... (Attempt 70/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2429 and retrying... (Attempt 71/1000)
# val set for label Consolidation does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2430 and retrying... (Attempt 72/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2431 and retrying... (Attempt 73/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2432 and retrying... (Attempt 74/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2433 and retrying... (Attempt 75/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2434 and retrying... (Attempt 76/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2435 and retrying... (Attempt 77/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2436 and retrying... (Attempt 78/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2437 and retrying... (Attempt 79/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2438 and retrying... (Attempt 80/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2439 and retrying... (Attempt 81/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2440 and retrying... (Attempt 82/1000)
# val set for label Mass/Nodule does not meet gender balance. M: 6, F: 1
# Conditions not met for val. Changing seed to 2441 and retrying... (Attempt 83/1000)
# val set for label Consolidation does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2442 and retrying... (Attempt 84/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 2443 and retrying... (Attempt 85/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 2444 and retrying... (Attempt 86/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2445 and retrying... (Attempt 87/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2446 and retrying... (Attempt 88/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2447 and retrying... (Attempt 89/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2448 and retrying... (Attempt 90/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2449 and retrying... (Attempt 91/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2450 and retrying... (Attempt 92/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2451 and retrying... (Attempt 93/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2452 and retrying... (Attempt 94/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2453 and retrying... (Attempt 95/1000)
# val set for label Consolidation does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2454 and retrying... (Attempt 96/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2455 and retrying... (Attempt 97/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2456 and retrying... (Attempt 98/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2457 and retrying... (Attempt 99/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2458 and retrying... (Attempt 100/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2459 and retrying... (Attempt 101/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2460 and retrying... (Attempt 102/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2461 and retrying... (Attempt 103/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2462 and retrying... (Attempt 104/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 3
# Conditions not met for val. Changing seed to 2463 and retrying... (Attempt 105/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2464 and retrying... (Attempt 106/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2465 and retrying... (Attempt 107/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2466 and retrying... (Attempt 108/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 2467 and retrying... (Attempt 109/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2468 and retrying... (Attempt 110/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2469 and retrying... (Attempt 111/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2470 and retrying... (Attempt 112/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2471 and retrying... (Attempt 113/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2472 and retrying... (Attempt 114/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2473 and retrying... (Attempt 115/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2474 and retrying... (Attempt 116/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2475 and retrying... (Attempt 117/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2476 and retrying... (Attempt 118/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2477 and retrying... (Attempt 119/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2478 and retrying... (Attempt 120/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2479 and retrying... (Attempt 121/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2480 and retrying... (Attempt 122/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2481 and retrying... (Attempt 123/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2482 and retrying... (Attempt 124/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2483 and retrying... (Attempt 125/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2484 and retrying... (Attempt 126/1000)
# val set for label Consolidation does not meet gender balance. M: 6, F: 1
# Conditions not met for val. Changing seed to 2485 and retrying... (Attempt 127/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2486 and retrying... (Attempt 128/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2487 and retrying... (Attempt 129/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2488 and retrying... (Attempt 130/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2489 and retrying... (Attempt 131/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2490 and retrying... (Attempt 132/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 2491 and retrying... (Attempt 133/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2492 and retrying... (Attempt 134/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2493 and retrying... (Attempt 135/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2494 and retrying... (Attempt 136/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 2495 and retrying... (Attempt 137/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2496 and retrying... (Attempt 138/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2497 and retrying... (Attempt 139/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2498 and retrying... (Attempt 140/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2499 and retrying... (Attempt 141/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2500 and retrying... (Attempt 142/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2501 and retrying... (Attempt 143/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2502 and retrying... (Attempt 144/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2503 and retrying... (Attempt 145/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 3
# Conditions not met for val. Changing seed to 2504 and retrying... (Attempt 146/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2505 and retrying... (Attempt 147/1000)
# val set for label Consolidation does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2506 and retrying... (Attempt 148/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2507 and retrying... (Attempt 149/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2508 and retrying... (Attempt 150/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2509 and retrying... (Attempt 151/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2510 and retrying... (Attempt 152/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2511 and retrying... (Attempt 153/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2512 and retrying... (Attempt 154/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2513 and retrying... (Attempt 155/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2514 and retrying... (Attempt 156/1000)
# val set for label Pneumonia does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2515 and retrying... (Attempt 157/1000)
# val set for label Consolidation does not meet gender balance. M: 6, F: 0
# Conditions not met for val. Changing seed to 2516 and retrying... (Attempt 158/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2517 and retrying... (Attempt 159/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2518 and retrying... (Attempt 160/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2519 and retrying... (Attempt 161/1000)
# val set for label Consolidation does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2520 and retrying... (Attempt 162/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 3
# Conditions not met for val. Changing seed to 2521 and retrying... (Attempt 163/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2522 and retrying... (Attempt 164/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2523 and retrying... (Attempt 165/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2524 and retrying... (Attempt 166/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2525 and retrying... (Attempt 167/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2526 and retrying... (Attempt 168/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2527 and retrying... (Attempt 169/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2528 and retrying... (Attempt 170/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2529 and retrying... (Attempt 171/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2530 and retrying... (Attempt 172/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2531 and retrying... (Attempt 173/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2532 and retrying... (Attempt 174/1000)
# val set for label Pneumonia does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2533 and retrying... (Attempt 175/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2534 and retrying... (Attempt 176/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2535 and retrying... (Attempt 177/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2536 and retrying... (Attempt 178/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2537 and retrying... (Attempt 179/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2538 and retrying... (Attempt 180/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2539 and retrying... (Attempt 181/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2540 and retrying... (Attempt 182/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 2541 and retrying... (Attempt 183/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2542 and retrying... (Attempt 184/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2543 and retrying... (Attempt 185/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2544 and retrying... (Attempt 186/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2545 and retrying... (Attempt 187/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2546 and retrying... (Attempt 188/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2547 and retrying... (Attempt 189/1000)
# val set for label Consolidation does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 2548 and retrying... (Attempt 190/1000)
# val set for label Pneumonia does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2549 and retrying... (Attempt 191/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2550 and retrying... (Attempt 192/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2551 and retrying... (Attempt 193/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2552 and retrying... (Attempt 194/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2553 and retrying... (Attempt 195/1000)
# val set for label Consolidation does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2554 and retrying... (Attempt 196/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2555 and retrying... (Attempt 197/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2556 and retrying... (Attempt 198/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2557 and retrying... (Attempt 199/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2558 and retrying... (Attempt 200/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2559 and retrying... (Attempt 201/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2560 and retrying... (Attempt 202/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2561 and retrying... (Attempt 203/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 2562 and retrying... (Attempt 204/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2563 and retrying... (Attempt 205/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2564 and retrying... (Attempt 206/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2565 and retrying... (Attempt 207/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2566 and retrying... (Attempt 208/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2567 and retrying... (Attempt 209/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2568 and retrying... (Attempt 210/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2569 and retrying... (Attempt 211/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2570 and retrying... (Attempt 212/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2571 and retrying... (Attempt 213/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2572 and retrying... (Attempt 214/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2573 and retrying... (Attempt 215/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 3
# Conditions not met for val. Changing seed to 2574 and retrying... (Attempt 216/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2575 and retrying... (Attempt 217/1000)
# val set for label Pneumonia does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2576 and retrying... (Attempt 218/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 3
# Conditions not met for val. Changing seed to 2577 and retrying... (Attempt 219/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2578 and retrying... (Attempt 220/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2579 and retrying... (Attempt 221/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2580 and retrying... (Attempt 222/1000)
# val set for label Consolidation does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2581 and retrying... (Attempt 223/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2582 and retrying... (Attempt 224/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 2583 and retrying... (Attempt 225/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2584 and retrying... (Attempt 226/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2585 and retrying... (Attempt 227/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2586 and retrying... (Attempt 228/1000)
# val set for label Pneumonia does not meet gender balance. M: 5, F: 0
# Conditions not met for val. Changing seed to 2587 and retrying... (Attempt 229/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2588 and retrying... (Attempt 230/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 2589 and retrying... (Attempt 231/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 3
# Conditions not met for val. Changing seed to 2590 and retrying... (Attempt 232/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 2591 and retrying... (Attempt 233/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2592 and retrying... (Attempt 234/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2593 and retrying... (Attempt 235/1000)
# Conditions met for val with seed 2593, 1
# Conditions met for val with seed 2358, 1
# Conditions met for train with seed 2358, 1
# Conditions met for train with seed 2358, 1
# 2358, old ratio 50
# Conditions met for val with seed 2358, 1
# val set for label Consolidation does not meet gender balance. M: 4, F: 1
# Conditions not met for val. Changing seed to 2359 and retrying... (Attempt 1/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 4, F: 1
# Conditions not met for val. Changing seed to 2360 and retrying... (Attempt 2/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 5, F: 1
# Conditions not met for val. Changing seed to 2361 and retrying... (Attempt 3/1000)
# Conditions met for val with seed 2361, 1
# Conditions met for train with seed 2358, 1
# Conditions met for train with seed 2358, 1
# 2358, old ratio 75
# Conditions met for val with seed 2358, 1
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2359 and retrying... (Attempt 1/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 2360 and retrying... (Attempt 2/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2361 and retrying... (Attempt 3/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2362 and retrying... (Attempt 4/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2363 and retrying... (Attempt 5/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 4, F: 1
# Conditions not met for val. Changing seed to 2364 and retrying... (Attempt 6/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 2365 and retrying... (Attempt 7/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2366 and retrying... (Attempt 8/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2367 and retrying... (Attempt 9/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2368 and retrying... (Attempt 10/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 2369 and retrying... (Attempt 11/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2370 and retrying... (Attempt 12/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2371 and retrying... (Attempt 13/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 2372 and retrying... (Attempt 14/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2373 and retrying... (Attempt 15/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 6, F: 1
# Conditions not met for val. Changing seed to 2374 and retrying... (Attempt 16/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2375 and retrying... (Attempt 17/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2376 and retrying... (Attempt 18/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2377 and retrying... (Attempt 19/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 2378 and retrying... (Attempt 20/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2379 and retrying... (Attempt 21/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2380 and retrying... (Attempt 22/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2381 and retrying... (Attempt 23/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2382 and retrying... (Attempt 24/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2383 and retrying... (Attempt 25/1000)
# val set for label Consolidation does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 2384 and retrying... (Attempt 26/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 2385 and retrying... (Attempt 27/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 4, F: 0
# Conditions not met for val. Changing seed to 2386 and retrying... (Attempt 28/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 4, F: 1
# Conditions not met for val. Changing seed to 2387 and retrying... (Attempt 29/1000)
# val set for label Consolidation does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 2388 and retrying... (Attempt 30/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 2389 and retrying... (Attempt 31/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 5, F: 1
# Conditions not met for val. Changing seed to 2390 and retrying... (Attempt 32/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 2391 and retrying... (Attempt 33/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 2392 and retrying... (Attempt 34/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 5, F: 1
# Conditions not met for val. Changing seed to 2393 and retrying... (Attempt 35/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 4, F: 1
# Conditions not met for val. Changing seed to 2394 and retrying... (Attempt 36/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 2395 and retrying... (Attempt 37/1000)
# Conditions met for val with seed 2395, 1
# Conditions met for train with seed 2358, 1
# Conditions met for train with seed 2358, 1
# 2358, old ratio 100
# Conditions met for val with seed 2358, 1
# Skipping val assignment for young as the ratio is 0.
# Conditions met for train with seed 2358, 1
# Skipping train assignment for young as the ratio is 0.
# 4563, old ratio 0
# Skipping val assignment for old as the ratio is 0.
# Conditions met for val with seed 4563, 1
# Skipping train assignment for old as the ratio is 0.
# Conditions met for train with seed 4563, 1
# 4563, old ratio 25
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 4565 and retrying... (Attempt 2/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 4
# Conditions not met for val. Changing seed to 4566 and retrying... (Attempt 3/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 4567 and retrying... (Attempt 4/1000)
# val set for label Pneumonia does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 4568 and retrying... (Attempt 5/1000)
# Conditions met for val with seed 4568, 1
# val set for label Consolidation does not meet gender balance. M: 10, F: 0
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 10, F: 1
# Conditions not met for val. Changing seed to 4565 and retrying... (Attempt 2/1000)
# Conditions met for val with seed 4565, 1
# Conditions met for train with seed 4563, 1
# Conditions met for train with seed 4563, 1
# 4563, old ratio 50
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 4565 and retrying... (Attempt 2/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 4
# Conditions not met for val. Changing seed to 4566 and retrying... (Attempt 3/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 4, F: 0
# Conditions not met for val. Changing seed to 4567 and retrying... (Attempt 4/1000)
# Conditions met for val with seed 4567, 1
# val set for label Consolidation does not meet gender balance. M: 5, F: 0
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 5, F: 1
# Conditions not met for val. Changing seed to 4565 and retrying... (Attempt 2/1000)
# Conditions met for val with seed 4565, 1
# Conditions met for train with seed 4563, 1
# Conditions met for train with seed 4563, 1
# 4563, old ratio 75
# Conditions met for val with seed 4563, 1
# val set for label Cardiomegaly does not meet gender balance. M: 4, F: 1
# Conditions not met for val. Changing seed to 4564 and retrying... (Attempt 1/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 4565 and retrying... (Attempt 2/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 4566 and retrying... (Attempt 3/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 4567 and retrying... (Attempt 4/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 4568 and retrying... (Attempt 5/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 4569 and retrying... (Attempt 6/1000)
# ...
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 98139 and retrying... (Attempt 229/1000)
# val set for label Consolidation does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 98140 and retrying... (Attempt 230/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98141 and retrying... (Attempt 231/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 98142 and retrying... (Attempt 232/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98143 and retrying... (Attempt 233/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 98144 and retrying... (Attempt 234/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98145 and retrying... (Attempt 235/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 98146 and retrying... (Attempt 236/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 98147 and retrying... (Attempt 237/1000)
# val set for label Consolidation does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 98148 and retrying... (Attempt 238/1000)
# val set for label Consolidation does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 98149 and retrying... (Attempt 239/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 98150 and retrying... (Attempt 240/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 98151 and retrying... (Attempt 241/1000)
# val set for label Consolidation does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 98152 and retrying... (Attempt 242/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 98153 and retrying... (Attempt 243/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 98154 and retrying... (Attempt 244/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 98155 and retrying... (Attempt 245/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98156 and retrying... (Attempt 246/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98157 and retrying... (Attempt 247/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 98158 and retrying... (Attempt 248/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98159 and retrying... (Attempt 249/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98160 and retrying... (Attempt 250/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 98161 and retrying... (Attempt 251/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 98162 and retrying... (Attempt 252/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 98163 and retrying... (Attempt 253/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 98164 and retrying... (Attempt 254/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 98165 and retrying... (Attempt 255/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 98166 and retrying... (Attempt 256/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 98167 and retrying... (Attempt 257/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 98168 and retrying... (Attempt 258/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 98169 and retrying... (Attempt 259/1000)
# val set for label Pneumonia does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 98170 and retrying... (Attempt 260/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 98171 and retrying... (Attempt 261/1000)
# val set for label Pneumonia does not meet gender balance. M: 4, F: 1
# Conditions not met for val. Changing seed to 98172 and retrying... (Attempt 262/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98173 and retrying... (Attempt 263/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 98174 and retrying... (Attempt 264/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 98175 and retrying... (Attempt 265/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 3
# Conditions not met for val. Changing seed to 98176 and retrying... (Attempt 266/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98177 and retrying... (Attempt 267/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 98178 and retrying... (Attempt 268/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 98179 and retrying... (Attempt 269/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98180 and retrying... (Attempt 270/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 98181 and retrying... (Attempt 271/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 98182 and retrying... (Attempt 272/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 98183 and retrying... (Attempt 273/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98184 and retrying... (Attempt 274/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 98185 and retrying... (Attempt 275/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 98186 and retrying... (Attempt 276/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 98187 and retrying... (Attempt 277/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98188 and retrying... (Attempt 278/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 98189 and retrying... (Attempt 279/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 98190 and retrying... (Attempt 280/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 98191 and retrying... (Attempt 281/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 98192 and retrying... (Attempt 282/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 98193 and retrying... (Attempt 283/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98194 and retrying... (Attempt 284/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 98195 and retrying... (Attempt 285/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 98196 and retrying... (Attempt 286/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 0
# Conditions not met for val. Changing seed to 98197 and retrying... (Attempt 287/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 98198 and retrying... (Attempt 288/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 98199 and retrying... (Attempt 289/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 98200 and retrying... (Attempt 290/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98201 and retrying... (Attempt 291/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 3
# Conditions not met for val. Changing seed to 98202 and retrying... (Attempt 292/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 98203 and retrying... (Attempt 293/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 98204 and retrying... (Attempt 294/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 4
# Conditions not met for val. Changing seed to 98205 and retrying... (Attempt 295/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 98206 and retrying... (Attempt 296/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 98207 and retrying... (Attempt 297/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 98208 and retrying... (Attempt 298/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 2
# Conditions not met for val. Changing seed to 98209 and retrying... (Attempt 299/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 98210 and retrying... (Attempt 300/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 98211 and retrying... (Attempt 301/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 98212 and retrying... (Attempt 302/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98213 and retrying... (Attempt 303/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98214 and retrying... (Attempt 304/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 98215 and retrying... (Attempt 305/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 0
# Conditions not met for val. Changing seed to 98216 and retrying... (Attempt 306/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 98217 and retrying... (Attempt 307/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98218 and retrying... (Attempt 308/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 98219 and retrying... (Attempt 309/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 98220 and retrying... (Attempt 310/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 98221 and retrying... (Attempt 311/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 98222 and retrying... (Attempt 312/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 3
# Conditions not met for val. Changing seed to 98223 and retrying... (Attempt 313/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 1, F: 0
# Conditions not met for val. Changing seed to 98224 and retrying... (Attempt 314/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 1
# Conditions not met for val. Changing seed to 98225 and retrying... (Attempt 315/1000)
# val set for label Pneumonia does not meet gender balance. M: 1, F: 1
# Conditions not met for val. Changing seed to 98226 and retrying... (Attempt 316/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 1
# Conditions not met for val. Changing seed to 98227 and retrying... (Attempt 317/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 4
# Conditions not met for val. Changing seed to 98228 and retrying... (Attempt 318/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 2
# Conditions not met for val. Changing seed to 98229 and retrying... (Attempt 319/1000)
# val set for label Consolidation does not meet gender balance. M: 4, F: 1
# Conditions not met for val. Changing seed to 98230 and retrying... (Attempt 320/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 98231 and retrying... (Attempt 321/1000)
# Conditions met for val with seed 98231, 1
# Conditions met for val with seed 97910, 1
# Conditions met for train with seed 97910, 1
# Conditions met for train with seed 97910, 1
# 97910, old ratio 50
# Conditions met for val with seed 97910, 1
# Conditions met for val with seed 97910, 1
# Conditions met for train with seed 97910, 1
# Conditions met for train with seed 97910, 1
# 97910, old ratio 75
# Conditions met for val with seed 97910, 1
# val set for label Cardiomegaly does not meet gender balance. M: 3, F: 1
# Conditions not met for val. Changing seed to 97911 and retrying... (Attempt 1/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 2, F: 0
# Conditions not met for val. Changing seed to 97912 and retrying... (Attempt 2/1000)
# val set for label Cardiomegaly does not meet gender balance. M: 0, F: 3
# Conditions not met for val. Changing seed to 97913 and retrying... (Attempt 3/1000)
# Conditions met for val with seed 97913, 1
# Conditions met for train with seed 97910, 1
# Conditions met for train with seed 97910, 1
# 97910, old ratio 100
# Conditions met for val with seed 97910, 1
# Skipping val assignment for young as the ratio is 0.
# Conditions met for train with seed 97910, 1
# Skipping train assignment for young as the ratio is 0.

# %%
diagnostic_labels = ['No Finding', 'Cardiomegaly', 'Consolidation', 'Infiltration', 'Mass/Nodule', 'Pneumonia']

# Function to calculate and print diagnostic label counts for each set
def print_label_counts(df, set_name):
    print(f"\nDiagnostic Label Counts for {set_name} Set:")
    for age_group in ['old', 'young']:
        print(f"Age Group: {age_group}")
        df_set = df[(df['Set'].str.contains(set_name)) & (df['Age Group'] == age_group)]
        label_counts = df_set[diagnostic_labels].sum()
        print(label_counts)

# Loop through each ratio and print the diagnostic label counts for test, val, and train sets
for seed_idx, seed in enumerate(predefined_seeds):
    for ratio_idx, (old_ratio, young_ratio) in enumerate(ratios):
        dataset_key = f'df_ratio_{old_ratio}_{young_ratio}_seed_{seed}'
        print(f"\nRatio {old_ratio}:{young_ratio}, Seed {seed}\n")
        
        # Print counts for test_old and test_young
        print_label_counts(dfs[dataset_key], 'test')
        
        # Print counts for validation set
        print_label_counts(dfs[dataset_key], 'val')
        
        # Print counts for training set
        print_label_counts(dfs[dataset_key], 'train')
# Out:
# Ratio 0:100, Seed 2358
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation      8
# Infiltration     113
# Mass/Nodule       37
# Pneumonia         68
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2761
# Cardiomegaly      122
# Consolidation     137
# Infiltration      879
# Mass/Nodule       302
# Pneumonia         528
# dtype: int64
#
# Ratio 25:75, Seed 2358
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       101
# Cardiomegaly       4
# Consolidation      8
# Infiltration      20
# Mass/Nodule        8
# Pneumonia          6
# dtype: int64
# Age Group: young
# No Finding       255
# Cardiomegaly      10
# Consolidation      8
# Infiltration      86
# Mass/Nodule       25
# Pneumonia         52
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       913
# Cardiomegaly      26
# Consolidation     68
# Infiltration     197
# Mass/Nodule       72
# Pneumonia         17
# dtype: int64
# Age Group: young
# No Finding       2062
# Cardiomegaly       87
# Consolidation      86
# Infiltration      663
# Mass/Nodule       220
# Pneumonia         372
# dtype: int64
#
# Ratio 50:50, Seed 2358
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       194
# Cardiomegaly       5
# Consolidation     12
# Infiltration      45
# Mass/Nodule       23
# Pneumonia          5
# dtype: int64
# Age Group: young
# No Finding       170
# Cardiomegaly       6
# Consolidation      7
# Infiltration      62
# Mass/Nodule       15
# Pneumonia         29
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2054
# Cardiomegaly       44
# Consolidation      88
# Infiltration      414
# Mass/Nodule       155
# Pneumonia          43
# dtype: int64
# Age Group: young
# No Finding       1372
# Cardiomegaly       60
# Consolidation      63
# Infiltration      435
# Mass/Nodule       140
# Pneumonia         242
# dtype: int64
#
# Ratio 75:25, Seed 2358
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       294
# Cardiomegaly       8
# Consolidation     19
# Infiltration      65
# Mass/Nodule       35
# Pneumonia         11
# dtype: int64
# Age Group: young
# No Finding       85
# Cardiomegaly      4
# Consolidation     5
# Infiltration     26
# Mass/Nodule      13
# Pneumonia        17
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2329
# Cardiomegaly      109
# Consolidation     169
# Infiltration      613
# Mass/Nodule       213
# Pneumonia          62
# dtype: int64
# Age Group: young
# No Finding       685
# Cardiomegaly      25
# Consolidation     29
# Infiltration     229
# Mass/Nodule       62
# Pneumonia        116
# dtype: int64
#
# Ratio 100:0, Seed 2358
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      10
# Consolidation     21
# Infiltration      93
# Mass/Nodule       43
# Pneumonia         16
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2606
# Cardiomegaly      122
# Consolidation     230
# Infiltration      828
# Mass/Nodule       261
# Pneumonia          83
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 4563
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       342
# Cardiomegaly      14
# Consolidation     12
# Infiltration     110
# Mass/Nodule       47
# Pneumonia         68
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2742
# Cardiomegaly      101
# Consolidation     119
# Infiltration      918
# Mass/Nodule       282
# Pneumonia         504
# dtype: int64
#
# Ratio 25:75, Seed 4563
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       99
# Cardiomegaly      4
# Consolidation     7
# Infiltration     20
# Mass/Nodule       9
# Pneumonia         7
# dtype: int64
# Age Group: young
# No Finding       255
# Cardiomegaly      10
# Consolidation     14
# Infiltration      79
# Mass/Nodule       22
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1002
# Cardiomegaly       16
# Consolidation      60
# Infiltration      186
# Mass/Nodule       100
# Pneumonia          25
# dtype: int64
# Age Group: young
# No Finding       2061
# Cardiomegaly       75
# Consolidation      94
# Infiltration      680
# Mass/Nodule       216
# Pneumonia         384
# dtype: int64
#
# Ratio 50:50, Seed 4563
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       201
# Cardiomegaly       5
# Consolidation     11
# Infiltration      47
# Mass/Nodule       21
# Pneumonia         12
# dtype: int64
# Age Group: young
# No Finding       170
# Cardiomegaly       7
# Consolidation     11
# Infiltration      52
# Mass/Nodule       12
# Pneumonia         34
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1981
# Cardiomegaly       72
# Consolidation     122
# Infiltration      400
# Mass/Nodule       135
# Pneumonia          46
# dtype: int64
# Age Group: young
# No Finding       1374
# Cardiomegaly       56
# Consolidation      53
# Infiltration      454
# Mass/Nodule       158
# Pneumonia         241
# dtype: int64
#
# Ratio 75:25, Seed 4563
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       300
# Cardiomegaly       7
# Consolidation     14
# Infiltration      66
# Mass/Nodule       34
# Pneumonia         14
# dtype: int64
# Age Group: young
# No Finding       87
# Cardiomegaly      4
# Consolidation     5
# Infiltration     31
# Mass/Nodule      10
# Pneumonia        12
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2358
# Cardiomegaly      105
# Consolidation     175
# Infiltration      613
# Mass/Nodule       199
# Pneumonia          61
# dtype: int64
# Age Group: young
# No Finding       690
# Cardiomegaly      25
# Consolidation     19
# Infiltration     230
# Mass/Nodule       76
# Pneumonia        130
# dtype: int64
#
# Ratio 100:0, Seed 4563
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       399
# Cardiomegaly      12
# Consolidation     17
# Infiltration      92
# Mass/Nodule       41
# Pneumonia         19
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2610
# Cardiomegaly      120
# Consolidation     234
# Infiltration      829
# Mass/Nodule       263
# Pneumonia          80
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 7894
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       343
# Cardiomegaly      16
# Consolidation     15
# Infiltration     105
# Mass/Nodule       39
# Pneumonia         58
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2756
# Cardiomegaly      109
# Consolidation     129
# Infiltration      904
# Mass/Nodule       295
# Pneumonia         527
# dtype: int64
#
# Ratio 25:75, Seed 7894
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       100
# Cardiomegaly       4
# Consolidation      5
# Infiltration      22
# Mass/Nodule        9
# Pneumonia          5
# dtype: int64
# Age Group: young
# No Finding       257
# Cardiomegaly      11
# Consolidation     14
# Infiltration      78
# Mass/Nodule       30
# Pneumonia         47
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       974
# Cardiomegaly      19
# Consolidation     64
# Infiltration     201
# Mass/Nodule       71
# Pneumonia         18
# dtype: int64
# Age Group: young
# No Finding       2067
# Cardiomegaly       85
# Consolidation      85
# Infiltration      687
# Mass/Nodule       226
# Pneumonia         383
# dtype: int64
#
# Ratio 50:50, Seed 7894
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       197
# Cardiomegaly       5
# Consolidation      8
# Infiltration      46
# Mass/Nodule       21
# Pneumonia          7
# dtype: int64
# Age Group: young
# No Finding       172
# Cardiomegaly       7
# Consolidation      9
# Infiltration      52
# Mass/Nodule       22
# Pneumonia         34
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1873
# Cardiomegaly       74
# Consolidation     123
# Infiltration      402
# Mass/Nodule       107
# Pneumonia          54
# dtype: int64
# Age Group: young
# No Finding       1378
# Cardiomegaly       61
# Consolidation      58
# Infiltration      433
# Mass/Nodule       153
# Pneumonia         250
# dtype: int64
#
# Ratio 75:25, Seed 7894
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       297
# Cardiomegaly       8
# Consolidation     12
# Infiltration      71
# Mass/Nodule       30
# Pneumonia         11
# dtype: int64
# Age Group: young
# No Finding       85
# Cardiomegaly      8
# Consolidation     8
# Infiltration     23
# Mass/Nodule       6
# Pneumonia        13
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2463
# Cardiomegaly       74
# Consolidation     174
# Infiltration      615
# Mass/Nodule       210
# Pneumonia          63
# dtype: int64
# Age Group: young
# No Finding       691
# Cardiomegaly      35
# Consolidation     37
# Infiltration     226
# Mass/Nodule       64
# Pneumonia        116
# dtype: int64
#
# Ratio 100:0, Seed 7894
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       400
# Cardiomegaly       8
# Consolidation     19
# Infiltration      97
# Mass/Nodule       41
# Pneumonia         14
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2609
# Cardiomegaly      124
# Consolidation     232
# Infiltration      824
# Mass/Nodule       263
# Pneumonia          85
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 13289
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       341
# Cardiomegaly      12
# Consolidation     20
# Infiltration     109
# Mass/Nodule       38
# Pneumonia         76
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2743
# Cardiomegaly      109
# Consolidation     120
# Infiltration      896
# Mass/Nodule       288
# Pneumonia         511
# dtype: int64
#
# Ratio 25:75, Seed 13289
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       91
# Cardiomegaly      4
# Consolidation     4
# Infiltration     20
# Mass/Nodule       8
# Pneumonia         5
# dtype: int64
# Age Group: young
# No Finding       255
# Cardiomegaly       8
# Consolidation     14
# Infiltration      83
# Mass/Nodule       29
# Pneumonia         60
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       946
# Cardiomegaly      52
# Consolidation     42
# Infiltration     197
# Mass/Nodule       48
# Pneumonia         28
# dtype: int64
# Age Group: young
# No Finding       2059
# Cardiomegaly       85
# Consolidation      94
# Infiltration      687
# Mass/Nodule       209
# Pneumonia         383
# dtype: int64
#
# Ratio 50:50, Seed 13289
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       205
# Cardiomegaly       6
# Consolidation      6
# Infiltration      49
# Mass/Nodule       21
# Pneumonia          6
# dtype: int64
# Age Group: young
# No Finding       170
# Cardiomegaly       6
# Consolidation      9
# Infiltration      56
# Mass/Nodule       16
# Pneumonia         39
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1955
# Cardiomegaly       48
# Consolidation     109
# Infiltration      408
# Mass/Nodule       154
# Pneumonia          41
# dtype: int64
# Age Group: young
# No Finding       1373
# Cardiomegaly       64
# Consolidation      67
# Infiltration      445
# Mass/Nodule       140
# Pneumonia         270
# dtype: int64
#
# Ratio 75:25, Seed 13289
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       296
# Cardiomegaly       8
# Consolidation     10
# Infiltration      68
# Mass/Nodule       37
# Pneumonia         10
# dtype: int64
# Age Group: young
# No Finding       85
# Cardiomegaly      5
# Consolidation     4
# Infiltration     28
# Mass/Nodule       8
# Pneumonia        17
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2323
# Cardiomegaly       97
# Consolidation     178
# Infiltration      616
# Mass/Nodule       189
# Pneumonia          70
# dtype: int64
# Age Group: young
# No Finding       689
# Cardiomegaly      28
# Consolidation     27
# Infiltration     224
# Mass/Nodule       62
# Pneumonia        123
# dtype: int64
#
# Ratio 100:0, Seed 13289
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       402
# Cardiomegaly       9
# Consolidation     17
# Infiltration      93
# Mass/Nodule       50
# Pneumonia         16
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2607
# Cardiomegaly      123
# Consolidation     234
# Infiltration      828
# Mass/Nodule       254
# Pneumonia          83
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 15892
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       341
# Cardiomegaly       9
# Consolidation     18
# Infiltration     119
# Mass/Nodule       29
# Pneumonia         66
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2771
# Cardiomegaly      120
# Consolidation     122
# Infiltration      897
# Mass/Nodule       280
# Pneumonia         481
# dtype: int64
#
# Ratio 25:75, Seed 15892
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       99
# Cardiomegaly      4
# Consolidation     6
# Infiltration     19
# Mass/Nodule      13
# Pneumonia         4
# dtype: int64
# Age Group: young
# No Finding       255
# Cardiomegaly       6
# Consolidation     16
# Infiltration      88
# Mass/Nodule       19
# Pneumonia         50
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1015
# Cardiomegaly       28
# Consolidation      57
# Infiltration      197
# Mass/Nodule        73
# Pneumonia          18
# dtype: int64
# Age Group: young
# No Finding       2078
# Cardiomegaly       74
# Consolidation      98
# Infiltration      673
# Mass/Nodule       228
# Pneumonia         382
# dtype: int64
#
# Ratio 50:50, Seed 15892
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       203
# Cardiomegaly       4
# Consolidation      8
# Infiltration      45
# Mass/Nodule       21
# Pneumonia         10
# dtype: int64
# Age Group: young
# No Finding       170
# Cardiomegaly       5
# Consolidation     11
# Infiltration      56
# Mass/Nodule       12
# Pneumonia         30
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1965
# Cardiomegaly       77
# Consolidation      91
# Infiltration      406
# Mass/Nodule       132
# Pneumonia          53
# dtype: int64
# Age Group: young
# No Finding       1395
# Cardiomegaly       69
# Consolidation      62
# Infiltration      447
# Mass/Nodule       131
# Pneumonia         243
# dtype: int64
#
# Ratio 75:25, Seed 15892
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       298
# Cardiomegaly       7
# Consolidation     15
# Infiltration      70
# Mass/Nodule       33
# Pneumonia         11
# dtype: int64
# Age Group: young
# No Finding       85
# Cardiomegaly      5
# Consolidation     5
# Infiltration     28
# Mass/Nodule       9
# Pneumonia        15
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2377
# Cardiomegaly      101
# Consolidation     177
# Infiltration      599
# Mass/Nodule       217
# Pneumonia          65
# dtype: int64
# Age Group: young
# No Finding       695
# Cardiomegaly      24
# Consolidation     32
# Infiltration     225
# Mass/Nodule       75
# Pneumonia        128
# dtype: int64
#
# Ratio 100:0, Seed 15892
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       402
# Cardiomegaly      11
# Consolidation     20
# Infiltration      94
# Mass/Nodule       38
# Pneumonia         16
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2607
# Cardiomegaly      121
# Consolidation     231
# Infiltration      827
# Mass/Nodule       266
# Pneumonia          83
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 19756
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       344
# Cardiomegaly      11
# Consolidation     13
# Infiltration     109
# Mass/Nodule       40
# Pneumonia         65
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2769
# Cardiomegaly      118
# Consolidation     110
# Infiltration      884
# Mass/Nodule       307
# Pneumonia         494
# dtype: int64
#
# Ratio 25:75, Seed 19756
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       100
# Cardiomegaly       4
# Consolidation      5
# Infiltration      21
# Mass/Nodule       13
# Pneumonia          4
# dtype: int64
# Age Group: young
# No Finding       258
# Cardiomegaly      10
# Consolidation      9
# Infiltration      83
# Mass/Nodule       30
# Pneumonia         49
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1079
# Cardiomegaly       13
# Consolidation      70
# Infiltration      201
# Mass/Nodule        79
# Pneumonia          22
# dtype: int64
# Age Group: young
# No Finding       2079
# Cardiomegaly       78
# Consolidation      91
# Infiltration      677
# Mass/Nodule       218
# Pneumonia         381
# dtype: int64
#
# Ratio 50:50, Seed 19756
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       190
# Cardiomegaly       5
# Consolidation     10
# Infiltration      43
# Mass/Nodule       23
# Pneumonia         14
# dtype: int64
# Age Group: young
# No Finding       173
# Cardiomegaly       6
# Consolidation      5
# Infiltration      58
# Mass/Nodule       18
# Pneumonia         31
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2017
# Cardiomegaly       60
# Consolidation     100
# Infiltration      395
# Mass/Nodule       144
# Pneumonia          36
# dtype: int64
# Age Group: young
# No Finding       1390
# Cardiomegaly       60
# Consolidation      61
# Infiltration      427
# Mass/Nodule       134
# Pneumonia         243
# dtype: int64
#
# Ratio 75:25, Seed 19756
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       290
# Cardiomegaly       6
# Consolidation     18
# Infiltration      69
# Mass/Nodule       32
# Pneumonia         17
# dtype: int64
# Age Group: young
# No Finding       87
# Cardiomegaly      4
# Consolidation     7
# Infiltration     25
# Mass/Nodule       7
# Pneumonia        15
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2433
# Cardiomegaly      108
# Consolidation     151
# Infiltration      609
# Mass/Nodule       220
# Pneumonia          46
# dtype: int64
# Age Group: young
# No Finding       685
# Cardiomegaly      30
# Consolidation     24
# Infiltration     229
# Mass/Nodule       67
# Pneumonia        121
# dtype: int64
#
# Ratio 100:0, Seed 19756
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       398
# Cardiomegaly       9
# Consolidation     14
# Infiltration      98
# Mass/Nodule       46
# Pneumonia         17
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2611
# Cardiomegaly      123
# Consolidation     237
# Infiltration      823
# Mass/Nodule       258
# Pneumonia          82
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 23890
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       344
# Cardiomegaly       9
# Consolidation      9
# Infiltration     107
# Mass/Nodule       39
# Pneumonia         66
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2767
# Cardiomegaly      104
# Consolidation     125
# Infiltration      910
# Mass/Nodule       298
# Pneumonia         500
# dtype: int64
#
# Ratio 25:75, Seed 23890
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       99
# Cardiomegaly      4
# Consolidation     4
# Infiltration     24
# Mass/Nodule      10
# Pneumonia         5
# dtype: int64
# Age Group: young
# No Finding       255
# Cardiomegaly       6
# Consolidation      5
# Infiltration      84
# Mass/Nodule       27
# Pneumonia         45
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       894
# Cardiomegaly      56
# Consolidation     41
# Infiltration     181
# Mass/Nodule       84
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       2069
# Cardiomegaly       81
# Consolidation      93
# Infiltration      676
# Mass/Nodule       223
# Pneumonia         376
# dtype: int64
#
# Ratio 50:50, Seed 23890
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       203
# Cardiomegaly       5
# Consolidation     11
# Infiltration      45
# Mass/Nodule       20
# Pneumonia         11
# dtype: int64
# Age Group: young
# No Finding       173
# Cardiomegaly       6
# Consolidation      7
# Infiltration      57
# Mass/Nodule       22
# Pneumonia         31
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1963
# Cardiomegaly       88
# Consolidation     112
# Infiltration      412
# Mass/Nodule       123
# Pneumonia          40
# dtype: int64
# Age Group: young
# No Finding       1379
# Cardiomegaly       60
# Consolidation      52
# Infiltration      428
# Mass/Nodule       170
# Pneumonia         245
# dtype: int64
#
# Ratio 75:25, Seed 23890
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       296
# Cardiomegaly       7
# Consolidation     14
# Infiltration      70
# Mass/Nodule       31
# Pneumonia         14
# dtype: int64
# Age Group: young
# No Finding       85
# Cardiomegaly      8
# Consolidation     4
# Infiltration     24
# Mass/Nodule       6
# Pneumonia        13
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2359
# Cardiomegaly      104
# Consolidation     182
# Infiltration      607
# Mass/Nodule       214
# Pneumonia          60
# dtype: int64
# Age Group: young
# No Finding       696
# Cardiomegaly      25
# Consolidation     26
# Infiltration     225
# Mass/Nodule       68
# Pneumonia        128
# dtype: int64
#
# Ratio 100:0, Seed 23890
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       402
# Cardiomegaly       9
# Consolidation     17
# Infiltration      96
# Mass/Nodule       43
# Pneumonia         19
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2607
# Cardiomegaly      123
# Consolidation     234
# Infiltration      825
# Mass/Nodule       261
# Pneumonia          80
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 27456
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       341
# Cardiomegaly      13
# Consolidation     21
# Infiltration     109
# Mass/Nodule       43
# Pneumonia         72
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2759
# Cardiomegaly      118
# Consolidation     120
# Infiltration      894
# Mass/Nodule       291
# Pneumonia         500
# dtype: int64
#
# Ratio 25:75, Seed 27456
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       98
# Cardiomegaly      5
# Consolidation     6
# Infiltration     20
# Mass/Nodule       7
# Pneumonia         6
# dtype: int64
# Age Group: young
# No Finding       255
# Cardiomegaly       9
# Consolidation     18
# Infiltration      81
# Mass/Nodule       33
# Pneumonia         57
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       998
# Cardiomegaly      14
# Consolidation     62
# Infiltration     207
# Mass/Nodule       86
# Pneumonia         14
# dtype: int64
# Age Group: young
# No Finding       2069
# Cardiomegaly       84
# Consolidation      86
# Infiltration      675
# Mass/Nodule       202
# Pneumonia         385
# dtype: int64
#
# Ratio 50:50, Seed 27456
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       195
# Cardiomegaly       5
# Consolidation      9
# Infiltration      46
# Mass/Nodule       24
# Pneumonia          9
# dtype: int64
# Age Group: young
# No Finding       170
# Cardiomegaly       7
# Consolidation     11
# Infiltration      55
# Mass/Nodule       22
# Pneumonia         33
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1998
# Cardiomegaly       60
# Consolidation      99
# Infiltration      420
# Mass/Nodule       135
# Pneumonia          41
# dtype: int64
# Age Group: young
# No Finding       1373
# Cardiomegaly       70
# Consolidation      51
# Infiltration      451
# Mass/Nodule       147
# Pneumonia         246
# dtype: int64
#
# Ratio 75:25, Seed 27456
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       298
# Cardiomegaly       6
# Consolidation     14
# Infiltration      71
# Mass/Nodule       36
# Pneumonia         14
# dtype: int64
# Age Group: young
# No Finding       85
# Cardiomegaly      6
# Consolidation     4
# Infiltration     26
# Mass/Nodule      10
# Pneumonia        15
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2282
# Cardiomegaly       70
# Consolidation     182
# Infiltration      628
# Mass/Nodule       201
# Pneumonia          64
# dtype: int64
# Age Group: young
# No Finding       686
# Cardiomegaly      37
# Consolidation     29
# Infiltration     222
# Mass/Nodule       68
# Pneumonia        108
# dtype: int64
#
# Ratio 100:0, Seed 27456
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       401
# Cardiomegaly      10
# Consolidation     16
# Infiltration      97
# Mass/Nodule       41
# Pneumonia         19
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2608
# Cardiomegaly      122
# Consolidation     235
# Infiltration      824
# Mass/Nodule       263
# Pneumonia          80
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 30890
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       343
# Cardiomegaly      10
# Consolidation     13
# Infiltration     103
# Mass/Nodule       48
# Pneumonia         69
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2752
# Cardiomegaly      112
# Consolidation     127
# Infiltration      887
# Mass/Nodule       276
# Pneumonia         497
# dtype: int64
#
# Ratio 25:75, Seed 30890
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       97
# Cardiomegaly      5
# Consolidation     5
# Infiltration     21
# Mass/Nodule       9
# Pneumonia         7
# dtype: int64
# Age Group: young
# No Finding       255
# Cardiomegaly       8
# Consolidation      8
# Infiltration      78
# Mass/Nodule       38
# Pneumonia         54
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1012
# Cardiomegaly       27
# Consolidation      66
# Infiltration      202
# Mass/Nodule        65
# Pneumonia          22
# dtype: int64
# Age Group: young
# No Finding       2060
# Cardiomegaly       92
# Consolidation      91
# Infiltration      680
# Mass/Nodule       220
# Pneumonia         381
# dtype: int64
#
# Ratio 50:50, Seed 30890
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       196
# Cardiomegaly       5
# Consolidation      6
# Infiltration      44
# Mass/Nodule       27
# Pneumonia          9
# dtype: int64
# Age Group: young
# No Finding       171
# Cardiomegaly       8
# Consolidation      8
# Infiltration      53
# Mass/Nodule       19
# Pneumonia         32
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1951
# Cardiomegaly       69
# Consolidation     133
# Infiltration      396
# Mass/Nodule       127
# Pneumonia          38
# dtype: int64
# Age Group: young
# No Finding       1379
# Cardiomegaly       51
# Consolidation      58
# Infiltration      448
# Mass/Nodule       157
# Pneumonia         263
# dtype: int64
#
# Ratio 75:25, Seed 30890
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       297
# Cardiomegaly       8
# Consolidation     13
# Infiltration      72
# Mass/Nodule       34
# Pneumonia         13
# dtype: int64
# Age Group: young
# No Finding       85
# Cardiomegaly      6
# Consolidation     4
# Infiltration     25
# Mass/Nodule      12
# Pneumonia        19
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2389
# Cardiomegaly       95
# Consolidation     172
# Infiltration      606
# Mass/Nodule       205
# Pneumonia          55
# dtype: int64
# Age Group: young
# No Finding       684
# Cardiomegaly      30
# Consolidation     26
# Infiltration     227
# Mass/Nodule       69
# Pneumonia        111
# dtype: int64
#
# Ratio 100:0, Seed 30890
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       396
# Cardiomegaly      11
# ...
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       341
# Cardiomegaly       9
# Consolidation     11
# Infiltration     117
# Mass/Nodule       40
# Pneumonia         60
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2766
# Cardiomegaly      119
# Consolidation     129
# Infiltration      887
# Mass/Nodule       298
# Pneumonia         504
# dtype: int64
#
# Ratio 25:75, Seed 89357
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       105
# Cardiomegaly       5
# Consolidation      4
# Infiltration      19
# Mass/Nodule       11
# Pneumonia          6
# dtype: int64
# Age Group: young
# No Finding       255
# Cardiomegaly       7
# Consolidation      9
# Infiltration      84
# Mass/Nodule       28
# Pneumonia         42
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       984
# Cardiomegaly      46
# Consolidation     59
# Infiltration     200
# Mass/Nodule       62
# Pneumonia         21
# dtype: int64
# Age Group: young
# No Finding       2082
# Cardiomegaly       82
# Consolidation      83
# Infiltration      696
# Mass/Nodule       204
# Pneumonia         365
# dtype: int64
#
# Ratio 50:50, Seed 89357
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       190
# Cardiomegaly       6
# Consolidation      9
# Infiltration      45
# Mass/Nodule       21
# Pneumonia         10
# dtype: int64
# Age Group: young
# No Finding       172
# Cardiomegaly       8
# Consolidation     10
# Infiltration      60
# Mass/Nodule       13
# Pneumonia         29
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2000
# Cardiomegaly       79
# Consolidation      91
# Infiltration      409
# Mass/Nodule       143
# Pneumonia          42
# dtype: int64
# Age Group: young
# No Finding       1381
# Cardiomegaly       60
# Consolidation      65
# Infiltration      443
# Mass/Nodule       152
# Pneumonia         262
# dtype: int64
#
# Ratio 75:25, Seed 89357
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       293
# Cardiomegaly       8
# Consolidation     14
# Infiltration      69
# Mass/Nodule       33
# Pneumonia         12
# dtype: int64
# Age Group: young
# No Finding       86
# Cardiomegaly      7
# Consolidation     5
# Infiltration     21
# Mass/Nodule       8
# Pneumonia        15
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2318
# Cardiomegaly      104
# Consolidation     180
# Infiltration      615
# Mass/Nodule       196
# Pneumonia          68
# dtype: int64
# Age Group: young
# No Finding       684
# Cardiomegaly      32
# Consolidation     30
# Infiltration     230
# Mass/Nodule       67
# Pneumonia        133
# dtype: int64
#
# Ratio 100:0, Seed 89357
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       397
# Cardiomegaly      10
# Consolidation     19
# Infiltration      91
# Mass/Nodule       43
# Pneumonia         16
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2612
# Cardiomegaly      122
# Consolidation     232
# Infiltration      830
# Mass/Nodule       261
# Pneumonia          83
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 93450
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       343
# Cardiomegaly      18
# Consolidation     25
# Infiltration     105
# Mass/Nodule       39
# Pneumonia         61
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2750
# Cardiomegaly      115
# Consolidation     116
# Infiltration      900
# Mass/Nodule       299
# Pneumonia         499
# dtype: int64
#
# Ratio 25:75, Seed 93450
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       102
# Cardiomegaly       4
# Consolidation      8
# Infiltration      20
# Mass/Nodule        9
# Pneumonia          7
# dtype: int64
# Age Group: young
# No Finding       255
# Cardiomegaly      13
# Consolidation     20
# Infiltration      77
# Mass/Nodule       29
# Pneumonia         47
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1009
# Cardiomegaly       26
# Consolidation      51
# Infiltration      213
# Mass/Nodule        65
# Pneumonia          13
# dtype: int64
# Age Group: young
# No Finding       2067
# Cardiomegaly       88
# Consolidation      87
# Infiltration      682
# Mass/Nodule       211
# Pneumonia         359
# dtype: int64
#
# Ratio 50:50, Seed 93450
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       197
# Cardiomegaly       5
# Consolidation     12
# Infiltration      41
# Mass/Nodule       26
# Pneumonia          8
# dtype: int64
# Age Group: young
# No Finding       170
# Cardiomegaly      10
# Consolidation     13
# Infiltration      49
# Mass/Nodule       17
# Pneumonia         29
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1948
# Cardiomegaly       65
# Consolidation     112
# Infiltration      409
# Mass/Nodule       143
# Pneumonia          43
# dtype: int64
# Age Group: young
# No Finding       1374
# Cardiomegaly       46
# Consolidation      57
# Infiltration      444
# Mass/Nodule       153
# Pneumonia         242
# dtype: int64
#
# Ratio 75:25, Seed 93450
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       299
# Cardiomegaly       9
# Consolidation     11
# Infiltration      71
# Mass/Nodule       32
# Pneumonia         10
# dtype: int64
# Age Group: young
# No Finding       85
# Cardiomegaly      6
# Consolidation     4
# Infiltration     27
# Mass/Nodule       7
# Pneumonia        14
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2320
# Cardiomegaly       92
# Consolidation     170
# Infiltration      632
# Mass/Nodule       194
# Pneumonia          68
# dtype: int64
# Age Group: young
# No Finding       684
# Cardiomegaly      31
# Consolidation     27
# Infiltration     227
# Mass/Nodule       70
# Pneumonia        135
# dtype: int64
#
# Ratio 100:0, Seed 93450
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       396
# Cardiomegaly      10
# Consolidation     17
# Infiltration      94
# Mass/Nodule       46
# Pneumonia         14
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2613
# Cardiomegaly      122
# Consolidation     234
# Infiltration      827
# Mass/Nodule       258
# Pneumonia          85
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Ratio 0:100, Seed 97910
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       341
# Cardiomegaly      20
# Consolidation     11
# Infiltration     114
# Mass/Nodule       39
# Pneumonia         58
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
# Age Group: young
# No Finding       2762
# Cardiomegaly      113
# Consolidation     117
# Infiltration      882
# Mass/Nodule       291
# Pneumonia         495
# dtype: int64
#
# Ratio 25:75, Seed 97910
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       95
# Cardiomegaly      4
# Consolidation     8
# Infiltration     22
# Mass/Nodule       8
# Pneumonia         7
# dtype: int64
# Age Group: young
# No Finding       255
# Cardiomegaly      12
# Consolidation      8
# Infiltration      86
# Mass/Nodule       27
# Pneumonia         43
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       1034
# Cardiomegaly       26
# Consolidation      52
# Infiltration      226
# Mass/Nodule        53
# Pneumonia          19
# dtype: int64
# Age Group: young
# No Finding       2079
# Cardiomegaly       88
# Consolidation      88
# Infiltration      665
# Mass/Nodule       208
# Pneumonia         374
# dtype: int64
#
# Ratio 50:50, Seed 97910
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       207
# Cardiomegaly       5
# Consolidation      8
# Infiltration      50
# Mass/Nodule       17
# Pneumonia          6
# dtype: int64
# Age Group: young
# No Finding       170
# Cardiomegaly       8
# Consolidation      4
# Infiltration      59
# Mass/Nodule       19
# Pneumonia         25
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2055
# Cardiomegaly       40
# Consolidation     109
# Infiltration      397
# Mass/Nodule       163
# Pneumonia          38
# dtype: int64
# Age Group: young
# No Finding       1385
# Cardiomegaly       68
# Consolidation      58
# Infiltration      453
# Mass/Nodule       131
# Pneumonia         243
# dtype: int64
#
# Ratio 75:25, Seed 97910
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       306
# Cardiomegaly       8
# Consolidation     11
# Infiltration      73
# Mass/Nodule       27
# Pneumonia         12
# dtype: int64
# Age Group: young
# No Finding       87
# Cardiomegaly      7
# Consolidation     8
# Infiltration     25
# Mass/Nodule       7
# Pneumonia        17
# dtype: int64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2430
# Cardiomegaly       99
# Consolidation     172
# Infiltration      594
# Mass/Nodule       201
# Pneumonia          55
# dtype: int64
# Age Group: young
# No Finding       692
# Cardiomegaly      36
# Consolidation     27
# Infiltration     221
# Mass/Nodule       80
# Pneumonia        132
# dtype: int64
#
# Ratio 100:0, Seed 97910
#
#
# Diagnostic Label Counts for test Set:
# Age Group: old
# No Finding       403
# Cardiomegaly      11
# Consolidation     19
# Infiltration     105
# Mass/Nodule       29
# Pneumonia         20
# dtype: int64
# Age Group: young
# No Finding       341
# Cardiomegaly      14
# Consolidation     11
# Infiltration     109
# Mass/Nodule       45
# Pneumonia         53
# dtype: int64
#
# Diagnostic Label Counts for val Set:
# Age Group: old
# No Finding       404
# Cardiomegaly      12
# Consolidation     13
# Infiltration      95
# Mass/Nodule       39
# Pneumonia         17
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64
#
# Diagnostic Label Counts for train Set:
# Age Group: old
# No Finding       2605
# Cardiomegaly      120
# Consolidation     238
# Infiltration      826
# Mass/Nodule       265
# Pneumonia          82
# dtype: int64
# Age Group: young
# No Finding       0.0
# Cardiomegaly     0.0
# Consolidation    0.0
# Infiltration     0.0
# Mass/Nodule      0.0
# Pneumonia        0.0
# dtype: float64

# %%
import pandas as pd
import os
fives = ['0', '25', '50', '75', '100']
for seed in predefined_seeds:
    for five in fives:
        # Load the data
        file_path = parent + f'no_finding/metadata/aggregate_age_nf/aggregate_age_nf_seed_{seed}/age_{five}_seed_{seed}.csv' 
        if not os.path.exists(parent + f'no_finding/experiment/metadata_count/seed{seed}/'):
            os.makedirs(parent + f'no_finding/experiment/metadata_count/seed{seed}/', exist_ok=True)
        
        data = pd.read_csv(file_path)

        # Define the disease labels for summing up their counts
        disease_labels = ['No Finding', 'Cardiomegaly', 'Consolidation', 'Infiltration', 'Mass/Nodule', 'Pneumonia']

        # Group the data by 'Age Group' and 'Set', sum the counts for each disease label, and count the total images
        grouped_counts_diseases = data.groupby(['Age Group', 'Set']).agg(
            {**{label: 'sum' for label in disease_labels}, 'Image Index': 'count'}).reset_index()
            
        # Rename 'Image Index' column to 'Total Images'
        grouped_counts_diseases.rename(columns={'Image Index': 'Total Images'}, inplace=True)

        # Export to CSV
        output_file_path = parent + f'no_finding/experiment/metadata_count/seed{seed}/age_{five}_seed_{seed}.csv'  
        grouped_counts_diseases.to_csv(output_file_path, index=False)

        print(f"Data exported successfully to {output_file_path}")
# Out:
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed2358/age_0_seed_2358.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed2358/age_25_seed_2358.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed2358/age_50_seed_2358.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed2358/age_75_seed_2358.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed2358/age_100_seed_2358.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed4563/age_0_seed_4563.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed4563/age_25_seed_4563.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed4563/age_50_seed_4563.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed4563/age_75_seed_4563.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed4563/age_100_seed_4563.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed7894/age_0_seed_7894.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed7894/age_25_seed_7894.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed7894/age_50_seed_7894.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed7894/age_75_seed_7894.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed7894/age_100_seed_7894.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed13289/age_0_seed_13289.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed13289/age_25_seed_13289.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed13289/age_50_seed_13289.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed13289/age_75_seed_13289.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed13289/age_100_seed_13289.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed15892/age_0_seed_15892.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed15892/age_25_seed_15892.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed15892/age_50_seed_15892.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed15892/age_75_seed_15892.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed15892/age_100_seed_15892.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed19756/age_0_seed_19756.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed19756/age_25_seed_19756.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed19756/age_50_seed_19756.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed19756/age_75_seed_19756.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed19756/age_100_seed_19756.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed23890/age_0_seed_23890.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed23890/age_25_seed_23890.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed23890/age_50_seed_23890.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed23890/age_75_seed_23890.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed23890/age_100_seed_23890.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed27456/age_0_seed_27456.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed27456/age_25_seed_27456.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed27456/age_50_seed_27456.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed27456/age_75_seed_27456.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed27456/age_100_seed_27456.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed30890/age_0_seed_30890.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed30890/age_25_seed_30890.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed30890/age_50_seed_30890.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed30890/age_75_seed_30890.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed30890/age_100_seed_30890.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed34905/age_0_seed_34905.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed34905/age_25_seed_34905.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed34905/age_50_seed_34905.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed34905/age_75_seed_34905.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed34905/age_100_seed_34905.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed38764/age_0_seed_38764.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed38764/age_25_seed_38764.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed38764/age_50_seed_38764.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed38764/age_75_seed_38764.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed38764/age_100_seed_38764.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed42136/age_0_seed_42136.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed42136/age_25_seed_42136.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed42136/age_50_seed_42136.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed42136/age_75_seed_42136.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed42136/age_100_seed_42136.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed46578/age_0_seed_46578.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed46578/age_25_seed_46578.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed46578/age_50_seed_46578.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed46578/age_75_seed_46578.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed46578/age_100_seed_46578.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed50349/age_0_seed_50349.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed50349/age_25_seed_50349.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed50349/age_50_seed_50349.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed50349/age_75_seed_50349.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed50349/age_100_seed_50349.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed54892/age_0_seed_54892.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed54892/age_25_seed_54892.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed54892/age_50_seed_54892.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed54892/age_75_seed_54892.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed54892/age_100_seed_54892.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed59871/age_0_seed_59871.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed59871/age_25_seed_59871.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed59871/age_50_seed_59871.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed59871/age_75_seed_59871.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed59871/age_100_seed_59871.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed63912/age_0_seed_63912.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed63912/age_25_seed_63912.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed63912/age_50_seed_63912.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed63912/age_75_seed_63912.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed63912/age_100_seed_63912.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed68354/age_0_seed_68354.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed68354/age_25_seed_68354.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed68354/age_50_seed_68354.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed68354/age_75_seed_68354.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed68354/age_100_seed_68354.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed72109/age_0_seed_72109.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed72109/age_25_seed_72109.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed72109/age_50_seed_72109.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed72109/age_75_seed_72109.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed72109/age_100_seed_72109.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed76845/age_0_seed_76845.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed76845/age_25_seed_76845.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed76845/age_50_seed_76845.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed76845/age_75_seed_76845.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed76845/age_100_seed_76845.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed80492/age_0_seed_80492.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed80492/age_25_seed_80492.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed80492/age_50_seed_80492.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed80492/age_75_seed_80492.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed80492/age_100_seed_80492.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed84910/age_0_seed_84910.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed84910/age_25_seed_84910.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed84910/age_50_seed_84910.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed84910/age_75_seed_84910.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed84910/age_100_seed_84910.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed89357/age_0_seed_89357.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed89357/age_25_seed_89357.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed89357/age_50_seed_89357.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed89357/age_75_seed_89357.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed89357/age_100_seed_89357.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed93450/age_0_seed_93450.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed93450/age_25_seed_93450.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed93450/age_50_seed_93450.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed93450/age_75_seed_93450.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed93450/age_100_seed_93450.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed97910/age_0_seed_97910.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed97910/age_25_seed_97910.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed97910/age_50_seed_97910.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed97910/age_75_seed_97910.csv
# Data exported successfully to /home/jkim/research/peds_cxr/no_finding/experiment/metadata_count/seed97910/age_100_seed_97910.csv
